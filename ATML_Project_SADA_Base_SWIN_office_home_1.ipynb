# %%
# !pip installed install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
# --------------------- Imports ------------------------- #

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
from torchvision import datasets, transforms, models
from torchvision.transforms import ToTensor
from torchvision.datasets import ImageFolder
from torchvision.models import vit_b_16

# Datasets
# from datasets import load_dataset
import kagglehub

# Extra
import os
from copy import deepcopy
from PIL import Image
import matplotlib.pyplot as plt
import timm

# %% [markdown]
# ## Office-31

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/ATML/Project/OfficeHomeDataset_10072016.zip -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00050.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00051.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00052.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00053.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00054.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00055.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00056.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00057.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00058.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00059.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00060.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00061.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00062.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00063.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00064.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00065.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00066.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00067.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00068.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00069.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00070.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00071.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00072.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00073.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00074.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00075.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00076.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00077.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00078.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00079.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00080.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00081.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00082.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00083.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00084.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00085.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00086.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00087.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00088.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00089.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00090.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00091.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00092.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00093.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00094.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00095.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00096.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00097.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00098.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Speaker/00099.jpg
#    creating: /content/OfficeHomeDataset_10072016/Product/Spoon/
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00001.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00002.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00003.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00004.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00005.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00006.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00007.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00008.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00009.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00010.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00011.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00012.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00013.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00014.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00015.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00016.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00017.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00018.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00019.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00020.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00021.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00022.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00023.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00024.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00025.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00026.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00027.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00028.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00029.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00030.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00031.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00032.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00033.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00034.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00035.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00036.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00037.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00038.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00039.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00040.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00041.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00042.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00043.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00044.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00045.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00046.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Spoon/00047.jpg
#    creating: /content/OfficeHomeDataset_10072016/Product/Table/
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00001.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00002.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00003.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00004.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00005.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00006.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00007.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00008.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00009.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00010.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00011.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00012.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00013.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00014.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00015.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00016.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00017.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00018.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00019.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00020.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00021.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00022.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00023.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00024.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00025.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00026.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00027.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00028.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00029.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00030.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00031.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00032.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00033.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00034.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00035.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00036.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00037.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00038.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00039.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00040.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00041.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00042.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00043.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00044.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00045.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00046.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00047.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00048.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00049.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00050.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00051.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00052.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00053.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00054.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00055.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00056.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00057.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00058.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00059.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Table/00060.jpg
#    creating: /content/OfficeHomeDataset_10072016/Product/Telephone/
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00001.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00002.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00003.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00004.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00005.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00006.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00007.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00008.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00009.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00010.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00011.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00012.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00013.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00014.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00015.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00016.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00017.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00018.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00019.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00020.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00021.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00022.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00023.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00024.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00025.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00026.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00027.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00028.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00029.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00030.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00031.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00032.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00033.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00034.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00035.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00036.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00037.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00038.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00039.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00040.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00041.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00042.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00043.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00044.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00045.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00046.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00047.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00048.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00049.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00050.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00051.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00052.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00053.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00054.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00055.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00056.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00057.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Telephone/00058.jpg
#    creating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00001.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00002.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00003.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00004.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00005.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00006.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00007.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00008.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00009.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00010.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00011.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00012.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00013.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00014.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00015.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00016.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00017.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00018.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00019.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00020.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00021.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00022.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00023.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00024.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00025.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00026.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00027.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00028.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00029.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00030.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00031.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00032.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00033.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00034.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00035.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00036.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00037.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00038.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00039.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00040.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00041.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/ToothBrush/00042.jpg
#    creating: /content/OfficeHomeDataset_10072016/Product/Toys/
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00001.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00002.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00003.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00004.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00005.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00006.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00007.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00008.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00009.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00010.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00011.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00012.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00013.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00014.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00015.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00016.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00017.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00018.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00019.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00020.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00021.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00022.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00023.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00024.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00025.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00026.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00027.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00028.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00029.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00030.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00031.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00032.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00033.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00034.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00035.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00036.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00037.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00038.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00039.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00040.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00041.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00042.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00043.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00044.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Toys/00045.jpg
#    creating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00001.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00002.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00003.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00004.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00005.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00006.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00007.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00008.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00009.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00010.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00011.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00012.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00013.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00014.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00015.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00016.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00017.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00018.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00019.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00020.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00021.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00022.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00023.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00024.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00025.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00026.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00027.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00028.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00029.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00030.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00031.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00032.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00033.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00034.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00035.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00036.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00037.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00038.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00039.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00040.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00041.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00042.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00043.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00044.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00045.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00046.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00047.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00048.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00049.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00050.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00051.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00052.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00053.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00054.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00055.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00056.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00057.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00058.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00059.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00060.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00061.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00062.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00063.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00064.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00065.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00066.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00067.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00068.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00069.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00070.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00071.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00072.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00073.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00074.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00075.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00076.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00077.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00078.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00079.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00080.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00081.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00082.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00083.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00084.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00085.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00086.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00087.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00088.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00089.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00090.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00091.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00092.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Trash_Can/00093.jpg
#    creating: /content/OfficeHomeDataset_10072016/Product/TV/
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00001.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00002.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00003.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00004.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00005.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00006.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00007.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00008.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00009.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00010.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00011.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00012.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00013.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00014.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00015.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00016.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00017.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00018.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00019.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00020.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00021.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00022.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00023.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00024.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00025.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00026.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00027.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00028.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00029.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00030.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00031.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00032.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00033.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00034.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00035.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00036.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00037.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00038.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00039.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00040.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00041.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00042.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00043.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00044.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00045.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00046.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00047.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00048.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00049.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00050.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00051.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00052.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00053.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00054.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00055.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00056.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00057.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00058.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00059.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00060.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00061.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00062.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00063.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00064.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00065.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00066.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00067.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00068.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00069.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00070.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00071.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00072.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00073.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00074.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00075.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/TV/00076.jpg
#    creating: /content/OfficeHomeDataset_10072016/Product/Webcam/
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00001.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00002.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00003.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00004.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00005.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00006.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00007.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00008.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00009.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00010.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00011.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00012.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00013.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00014.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00015.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00016.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00017.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00018.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00019.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00020.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00021.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00022.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00023.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00024.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00025.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00026.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00027.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00028.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00029.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00030.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00031.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00032.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00033.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00034.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00035.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00036.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00037.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00038.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00039.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00040.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00041.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00042.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00043.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00044.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00045.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00046.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00047.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00048.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00049.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00050.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00051.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00052.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00053.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00054.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00055.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00056.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00057.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00058.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00059.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00060.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00061.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00062.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00063.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00064.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00065.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00066.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00067.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00068.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00069.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00070.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00071.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00072.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00073.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00074.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00075.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00076.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00077.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00078.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00079.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00080.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00081.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00082.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00083.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00084.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00085.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00086.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00087.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00088.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00089.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00090.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00091.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00092.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00093.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00094.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00095.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00096.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00097.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Product/Webcam/00098.jpg
#    creating: /content/OfficeHomeDataset_10072016/Real World/
#    creating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00001.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00002.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00003.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00004.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00005.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00006.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00007.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00008.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00009.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00010.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00011.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00012.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00013.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00014.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00015.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00016.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00017.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00018.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00019.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00020.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00021.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00022.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00023.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00024.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00025.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00026.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00027.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00028.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00029.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00030.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00031.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00032.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00033.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00034.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00035.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00036.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00037.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00038.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00039.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00040.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00041.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00042.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00043.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00044.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00045.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Alarm_Clock/00046.jpg
# ...
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00051.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00052.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00053.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00054.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00055.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00056.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00057.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00058.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00059.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00060.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00061.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00062.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00063.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00064.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00065.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00066.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Toys/00067.jpg
#    creating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00001.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00002.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00003.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00004.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00005.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00006.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00007.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00008.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00009.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00010.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00011.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00012.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00013.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00014.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00015.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00016.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00017.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00018.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00019.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00020.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00021.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00022.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00023.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00024.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00025.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00026.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00027.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00028.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00029.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00030.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00031.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00032.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00033.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00034.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00035.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00036.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00037.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00038.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00039.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00040.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00041.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00042.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00043.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00044.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00045.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00046.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00047.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00048.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00049.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00050.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00051.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00052.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00053.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00054.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00055.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00056.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00057.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00058.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00059.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00060.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00061.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00062.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00063.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00064.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00065.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00066.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00067.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00068.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00069.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00070.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00071.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00072.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00073.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00074.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00075.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00076.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00077.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00078.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00079.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00080.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Trash_Can/00081.jpg
#    creating: /content/OfficeHomeDataset_10072016/Real World/TV/
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00001.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00002.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00003.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00004.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00005.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00006.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00007.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00008.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00009.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00010.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00011.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00012.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00013.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00014.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00015.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00016.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00017.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00018.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00019.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00020.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00021.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00022.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00023.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00024.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00025.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00026.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00027.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00028.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00029.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00030.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00031.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00032.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00033.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00034.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00035.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00036.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00037.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00038.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00039.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00040.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00041.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00042.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00043.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00044.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00045.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00046.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00047.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00048.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00049.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00050.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00051.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00052.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/TV/00053.jpg
#    creating: /content/OfficeHomeDataset_10072016/Real World/Webcam/
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00001.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00002.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00003.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00004.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00005.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00006.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00007.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00008.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00009.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00010.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00011.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00012.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00013.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00014.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00015.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00016.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00017.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00018.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00019.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00020.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00021.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00022.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00023.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00024.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00025.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00026.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00027.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00028.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00029.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00030.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00031.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00032.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00033.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00034.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00035.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00036.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00037.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00038.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00039.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00040.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00041.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00042.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00043.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00044.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00045.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00046.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00047.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00048.jpg
#   inflating: /content/OfficeHomeDataset_10072016/Real World/Webcam/00049.jpg

# %%
def Office31(domain, transform):
    # Download and set up the dataset path
    path = '/content/OfficeHomeDataset_10072016'
    path = os.path.join(path, domain)
    return datasets.ImageFolder(root=path, transform=transform)

def get_office_data_loaders(batch_size):

    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
    ])

    amazon_data = Office31("Art", transform)
    dslr_data = Office31("Clipart", transform)
    webcam_data = Office31("Product", transform)
    irl_data = Office31("Real World", transform)

    # Create data loaders
    loader_art = DataLoader(amazon_data, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
    loader_clp = DataLoader(dslr_data, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
    loader_prod = DataLoader(webcam_data, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
    loader_irl = DataLoader(irl_data, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)

    return loader_art, loader_clp, loader_prod, loader_irl

# %% [markdown]
# ## Pacs

# %% [markdown]
# ## Model Cards

# %%
class ResNetFeatureExtractor(nn.Module):
    def __init__(self, pretrained=True):
        super().__init__()
        base_model = torchvision.models.resnet50(pretrained=pretrained)
        self.conv1 = base_model.conv1
        self.bn1 = base_model.bn1
        self.relu = base_model.relu
        self.maxpool = base_model.maxpool
        self.layer1 = base_model.layer1
        self.layer2 = base_model.layer2
        self.layer3 = base_model.layer3
        self.layer4 = base_model.layer4

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool(x)

        f_block1 = self.layer1(x)
        f_block2 = self.layer2(f_block1)
        f_block3 = self.layer3(f_block2)
        f_block4 = self.layer4(f_block3)

        return f_block2, f_block3, f_block4




class VitBasicFeatureExtractor(nn.Module):

    def __init__(self, pretrained=True, layers=[4, 8, 12]):
        super().__init__()

        self.model = timm.create_model('vit_base_patch16_224', pretrained=pretrained, features_only=True)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

    def forward(self, x):

        features = self.model(x)
        pooled_features = []
        for feature in features:
            pooled = self.avgpool(feature)
            pooled = pooled.view(pooled.size(0), -1)
            pooled_features.append(pooled)

        return tuple(pooled_features)


class SwinBasicFeatureExtractor(nn.Module):
    def __init__(self, pretrained=True):

        super(SwinBasicFeatureExtractor, self).__init__()

        self.model = timm.create_model('swin_base_patch4_window7_224',
                                      pretrained=pretrained,
                                      features_only=True)

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

    def forward(self, x):

        all_features = self.model(x)

        pooled_features = []
        for feature in all_features:
            feature = feature.permute(0, 3, 1, 2)
            pooled = self.avgpool(feature)
            pooled = pooled.view(pooled.size(0), -1)
            pooled_features.append(pooled)

        return tuple(pooled_features[1:])

# %%
model = SwinBasicFeatureExtractor(pretrained=True)
input = torch.randn(1, 3, 224, 224)
output = model(input)

for feature in output:
    print(feature.shape)
# Out:
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# torch.Size([1, 256])
# torch.Size([1, 512])
# torch.Size([1, 1024])

# %%
import torch
import torch.nn as nn
import torch.nn.init as init

class SparseAutoencoder(nn.Module):

    def __init__(self, input_dim=2048, hidden_dim=1024, latent_dim=768, dropout_rate=0.3):
        super(SparseAutoencoder, self).__init__()

        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),

            nn.Linear(hidden_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),

            nn.Linear(hidden_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),

            nn.Linear(hidden_dim, latent_dim),
            nn.LayerNorm(latent_dim),
            nn.ReLU(inplace=True)
        )

        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),

            nn.Linear(hidden_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),

            nn.Linear(hidden_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),

            nn.Linear(hidden_dim, input_dim),
            nn.Sigmoid()
        )

        # Initialize weights
        self._initialize_weights()

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                # Kaiming initialization for layers followed by ReLU
                init.kaiming_uniform_(m.weight, a=0, nonlinearity='relu')
                if m.bias is not None:
                    init.zeros_(m.bias)
            elif isinstance(m, nn.LayerNorm):
                # Initialize LayerNorm with weight=1 and bias=0
                init.ones_(m.weight)
                init.zeros_(m.bias)

    def forward(self, x):
        z = self.encoder(x)
        x_recon = self.decoder(z)
        return x_recon, z

# %%
class BaselineModel(nn.Module):
    def __init__(self, feature_extractor, num_classes=31):

        super().__init__()
        self.feature_extractor = feature_extractor
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        self.classifier = nn.Linear(768, num_classes)

    def forward(self, x):
        _, _, f4 = self.feature_extractor(x)
        logits = self.classifier(f4)
        return logits, f4

# %%
class UnifiedModelMultiBlockSAE(nn.Module):
    def __init__(self,
                 sae_dim_block2=128,
                 sae_dim_block3=256,
                 sae_dim_block4=256,
                 num_classes=31):
        super().__init__()

        self.feature_extractor = SwinBasicFeatureExtractor(pretrained=True)
        self.sae4 = SparseAutoencoder(input_dim=1024, latent_dim=1024)
        self.classifier = nn.Sequential(
            nn.Linear(1024, num_classes)
        )

    def forward(self, x):
        _, _, f4 = self.feature_extractor(x)

        x_recon4, z4 = self.sae4(f4)

        class_logits = self.classifier(z4)

        return (class_logits,
                (x_recon4, z4),
                (f4))

# %% [markdown]
# ## Losses

# %%
def irm_penalty(logits, labels):

    scale = torch.tensor(1.0, requires_grad=True, device=logits.device)
    loss_erm = F.cross_entropy(scale * logits, labels)

    grad = torch.autograd.grad(loss_erm, [scale], create_graph=True)[0]

    penalty = torch.sum(grad**2)
    var = 0.0

    return loss_erm, penalty, var

# %%
def compute_sae_loss(recons, pools, zs, lambda_sparse=[1.0, 1.0, 1.0], lambda_reconstruction=[1.0, 1.0, 1.0]):

    x2_recon, x3_recon, x4_recon = recons
    f2p, f3p, f4p = pools
    z2, z3, z4 = zs

    rec_loss2 = F.mse_loss(x2_recon, f2p)
    rec_loss3 = F.mse_loss(x3_recon, f3p)
    rec_loss4 = F.mse_loss(x4_recon, f4p)

    lambda_r1, lambda_r2, lambda_r3 = lambda_reconstruction
    recon_loss_total = (lambda_r1 * rec_loss2 + lambda_r2 * rec_loss3 + lambda_r3 * rec_loss4)

    l1_z2 = torch.mean(torch.abs(z2))
    l1_z3 = torch.mean(torch.abs(z3))
    l1_z4 = torch.mean(torch.abs(z4))
    lambda_s1, lambda_s2, lambda_s3 = lambda_sparse
    l1_sparsity_total = (lambda_s1 * l1_z2 + lambda_s2 * l1_z3 + lambda_s3 * l1_z4)

    return recon_loss_total, l1_sparsity_total

# %% [markdown]
# ## Trian and Evaluate Functions

# %% [markdown]
# ### Train

# %%
def train_main_irm_multi_sae_office(model,
                              loader_source,
                              test_loader,
                              num_epochs=20,
                              lr=1e-4,
                              lr_sae=1e-4,
                              lambda_irm=1.0,
                              lambda_sae_rec=1.0,
                              lambda_sae_sparse=1e-4,
                              lambda_sparse=[1.0, 1.0, 1.0],
                              lambda_reconstruction=[1.0, 1.0, 1.0],
                              lambda_irm_pair=[1.0, 1.0, 1.0],
                              device='cuda',
                              verbose=False):

    model.to(device)
    model.train()

    def sae_forward_splits(f2p, f3p, f4p):
        x_recon2, z2 = model.sae2(f2p)
        x_recon3, z3 = model.sae3(f3p)
        x_recon4, z4 = model.sae4(f4p)
        return x_recon2, z2, x_recon3, z3, x_recon4, z4

    optimizer = optim.Adam(model.parameters(), lr=lr)

    for epoch in range(num_epochs):
        source_iter = iter(loader_source)
        steps_per_epoch = len(source_iter)

        for step in range(steps_per_epoch):

            try:
                x_s, y_s = next(source_iter)
            except StopIteration:
                source_iter = iter(loader_source)
                x_s, y_s = next(source_iter)

            x_s, y_s = x_s.to(device), y_s.to(device)

            class_logits_s, _, _, _, _ = model(x_s)

            loss_erm_s, penalty_s, var_s = irm_penalty(class_logits_s, y_s)

            irm_loss = 0.5 * (loss_erm_s)
            irm_pen  = 0.5 * (penalty_s)


            w1, w2, w3 = lambda_irm_pair
            loss_irm = w1 * (irm_loss) + w2 * (lambda_irm * irm_pen) + w3 * var_s


            with torch.no_grad():
                _, (x_recon2_s, z2_s), (x_recon3_s, z3_s), (x_recon4_s, z4_s), (f2p_s, f3p_s, f4p_s) = model(x_s)

            x_recon2_s, z2_s, x_recon3_s, z3_s, x_recon4_s, z4_s = sae_forward_splits(f2p_s, f3p_s, f4p_s)

            lambda_s1, lambda_s2, lambda_s3 = lambda_sparse
            lambda_r1, lambda_r2, lambda_r3 = lambda_reconstruction

            rec_loss2_s = F.mse_loss(x_recon2_s, f2p_s)
            rec_loss2   = lambda_r1 * (rec_loss2_s)

            rec_loss3_s = F.mse_loss(x_recon3_s, f3p_s)
            rec_loss3   = lambda_r2 * (rec_loss3_s)

            rec_loss4_s = F.mse_loss(x_recon4_s, f4p_s)
            rec_loss4   = lambda_r3 * (rec_loss4_s)

            rec_loss_total = (rec_loss2 + rec_loss3 + rec_loss4)

            l1_2_s = torch.mean(torch.abs(z2_s))
            l1_2   = lambda_s1 * (l1_2_s)

            l1_3_s = torch.mean(torch.abs(z3_s))
            l1_3   = lambda_s2 * (l1_3_s)

            l1_4_s = torch.mean(torch.abs(z4_s))
            l1_4   = lambda_s3 * (l1_4_s)

            l1_sparsity = l1_2 + l1_3 + l1_4

            sae_loss = lambda_sae_rec * rec_loss_total + lambda_sae_sparse * l1_sparsity

            loss = loss_irm + sae_loss

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            if (step+1) % 40 == 0 and verbose:
                print(f"Epoch [{epoch+1}/{num_epochs}], Step [{step+1}/{steps_per_epoch}], "
                      f"IRM Loss: {loss_irm.item():.4f}, SAE Loss: {sae_loss.item():.4f}")

        test_acc = evaluate(model, test_loader, device=device)
        print(f"** End of Epoch {epoch+1}/{num_epochs} | Test Accuracy: {test_acc:.2f}% **")

    return model

# %%
def train_model_irm_sae_with_warmup_office(
    batch_size=16,
    num_warmup_epochs=5,
    num_main_epochs=20,
    lr=1e-4,
    lr_sae=1e-4,
    lambda_irm=1.0,
    lambda_sae_rec=1.0,
    lambda_sae_sparse=1e-4,
    device='cuda',
    loader=['A', 'W'],
    model=None,
    verbose=False,
    lambda_sparse=[1.0, 1.0, 1.0],
    lambda_reconstruction=[1.0, 1.0, 1.0],
    lambda_irm_pair=[1.0, 1.0, 0.0],
):


    loader_art, loader_clp, loader_prod, loader_irl = get_office_data_loaders(batch_size)

    source, target = loader if loader is not None else ['A', 'C']

    if source == 'A':
        loader_source = loader_art
    elif source == 'C':
        loader_source = loader_clp
    elif source == 'P':
        loader_source = loader_prod
    elif source == 'R':
        loader_source = loader_irl

    if target == 'A':
        loader_target = loader_art
    elif target == 'C':
        loader_target = loader_clp
    elif target == 'P':
        loader_target = loader_prod
    elif target == 'R':
        loader_target = loader_irl


    if model is None:
        model = UnifiedModelMultiBlockSAE(512, 1024, 2048, 65)

    print("===== Main Phase (IRM + SAE) =====")

    model = train_main_irm_multi_sae_office(model,
                                            loader_source=loader_source,
                                            test_loader=loader_target,
                                            num_epochs=num_main_epochs,
                                            lr=lr,
                                            lr_sae=lr_sae,
                                            lambda_irm=lambda_irm,
                                            lambda_sae_rec=lambda_sae_rec,
                                            lambda_sae_sparse=lambda_sae_sparse,
                                            device=device,
                                            verbose=verbose,
                                            lambda_sparse=lambda_sparse,
                                            lambda_reconstruction=lambda_reconstruction,
                                            lambda_irm_pair=lambda_irm_pair
                                            )

    return model

# %% [markdown]
# ### Separate optm

# %%
def train_main_irm_multi_sae_office(
    model,
    loader_source,
    test_loader,
    num_epochs=20,
    lr=1e-4,
    lr_sae=1e-4,
    lambda_irm=1.0,
    lambda_sae_rec=1.0,
    lambda_sae_sparse=1e-4,
    lambda_sparse=[1.0, 1.0, 1.0],
    lambda_reconstruction=[1.0, 1.0, 1.0],
    lambda_irm_pair=[1.0, 1.0, 1.0],
    device='cuda',
    verbose=False
):
    import torch.optim as optim

    model.to(device)
    model.train()

    def sae_forward_splits(f4p):
        # x_recon2, z2 = model.sae2(f2p)
        # x_recon3, z3 = model.sae3(f3p)
        x_recon4, z4 = model.sae4(f4p)
        return x_recon4, z4

    # Define separate optimizers
    # Optimizer for the feature extractor and classifier
    params_rest = [
        p for n, p in model.named_parameters()
        if not (n.startswith('sae2') or n.startswith('sae3') or n.startswith('sae4'))
    ]
    # optimizer_rest = optim.SGD(params_rest, lr=lr, momentum=0.9)
    optimizer_rest = optim.Adam(params_rest, lr=lr)
    # Optimizer for the Sparse Autoencoders (sae2, sae3, sae4)
    params_sae = list(model.sae4.parameters())
    optimizer_sae = optim.Adam(params_sae, lr=lr_sae)

    for epoch in range(num_epochs):
        source_iter = iter(loader_source)
        steps_per_epoch = len(source_iter)

        for step in range(steps_per_epoch):

            try:
                x_s, y_s = next(source_iter)
            except StopIteration:
                source_iter = iter(loader_source)
                x_s, y_s = next(source_iter)

            x_s, y_s = x_s.to(device), y_s.to(device)

            # Forward pass for classification
            class_logits_s, _, _ = model(x_s)

            # Compute IRM loss
            loss_erm_s, penalty_s, var_s = irm_penalty(class_logits_s, y_s)

            irm_loss = 0.5 * loss_erm_s
            irm_pen  = 0.5 * penalty_s

            w1, w2, w3 = lambda_irm_pair
            loss_irm = w1 * irm_loss + w2 * (lambda_irm * irm_pen) + w3 * var_s

            # Forward pass for SAEs without tracking gradients
            with torch.no_grad():
                class_logits_s, (x_recon4_s, z4_s), (f4p_s) = model(x_s)

            # Forward pass through SAEs to get reconstructions and latent vectors
            x_recon4_s, z4_s = sae_forward_splits(f4p_s)

            # Compute Reconstruction Loss
            lambda_s1, lambda_s2, lambda_s3 = lambda_sparse
            lambda_r1, lambda_r2, lambda_r3 = lambda_reconstruction


            rec_loss4_s = F.mse_loss(x_recon4_s, f4p_s)
            rec_loss4   = lambda_r3 * rec_loss4_s

            rec_loss_total = rec_loss4

            l1_4_s = torch.mean(torch.abs(z4_s))
            l1_4   = lambda_s3 * l1_4_s

            l1_sparsity = l1_4

            # Total SAE Loss
            sae_loss = lambda_sae_rec * rec_loss_total + lambda_sae_sparse * l1_sparsity

            loss = loss_irm + sae_loss


            # Zero gradients for both optimizers
            optimizer_rest.zero_grad()
            optimizer_sae.zero_grad()

            # Backward pass
            loss.backward()

            # Update parameters
            optimizer_rest.step()
            optimizer_sae.step()

            if (step+1) % 40 == 0 and verbose:
                print(f"Epoch [{epoch+1}/{num_epochs}], Step [{step+1}/{steps_per_epoch}], "
                      f"IRM Loss: {loss_irm.item():.4f}, SAE Loss: {sae_loss.item():.4f}")

        # Evaluation after each epoch
        test_acc = evaluate(model, test_loader, device=device)
        print(f"** End of Epoch {epoch+1}/{num_epochs} | Test Accuracy: {test_acc:.2f}% **")

    return model

# %% [markdown]
# ### Evaluate

# %%
def evaluate_baseline(model, loader, device='cuda'):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            logits, _ = model(x)
            preds = torch.argmax(logits, dim=1)
            correct += (preds == y).sum().item()
            total += y.size(0)
    acc = 100.0 * correct / total
    model.train()
    return acc

# %%
def evaluate(model, loader, device='cuda'):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            logits, _, _ = model(x)
            preds = torch.argmax(logits, dim=1)
            correct += (preds == y).sum().item()
            total += y.size(0)
    acc = 100.0 * correct / total
    return acc

# %% [markdown]
# # MAIN

# %% [markdown]
# ### Ours

# %% [markdown]
# ##A -> D **DO** **NOT** **RUN**

# %%
combination = ["A", "D"]
print(f"------------Combination: {combination}--------------")
lambda_irm_pair = [10.0, 4.0, 0.0]
lambda_sparse=[0.1, 0.1, 0.1]

trained_model_sae_office = train_model_irm_sae_with_warmup_office(
            # model=trained_model_sae_office,
            batch_size=32,
            num_warmup_epochs=4,
            num_main_epochs=10,
            lr=1e-5,
            lr_sae=5e-5,
            lambda_irm=1.0,
            lambda_sae_rec=2.0,
            lambda_sae_sparse=2e-4,
            device='cuda',
            verbose=True,
            lambda_irm_pair=lambda_irm_pair,
            lambda_sparse=lambda_sparse,
            loader=combination
        )

print("--------------------------------------------")
# Out:
# ------------Combination: ['A', 'D']--------------
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Resuming download from 0 bytes (79538472 bytes left)...
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/xixuhu/office31?dataset_version_number=1 (0/79538472) bytes left.
# 100%|██████████| 75.9M/75.9M [00:04<00:00, 17.8MB/s]
# Extracting files...
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/89], IRM Loss: 16.9484, SAE Loss: 24.5316
# Epoch [1/10], Step [80/89], IRM Loss: 15.9215, SAE Loss: 7.4968
# ** End of Epoch 1/10 | Test Accuracy: 32.33% **
# Epoch [2/10], Step [40/89], IRM Loss: 10.5335, SAE Loss: 2.8149
# Epoch [2/10], Step [80/89], IRM Loss: 6.2005, SAE Loss: 3.8766
# ** End of Epoch 2/10 | Test Accuracy: 76.10% **
# Epoch [3/10], Step [40/89], IRM Loss: 2.9101, SAE Loss: 3.6661
# Epoch [3/10], Step [80/89], IRM Loss: 2.2937, SAE Loss: 3.8711
# ** End of Epoch 3/10 | Test Accuracy: 88.68% **
# Epoch [4/10], Step [40/89], IRM Loss: 1.3317, SAE Loss: 4.4993
# Epoch [4/10], Step [80/89], IRM Loss: 0.5690, SAE Loss: 3.6851
# ** End of Epoch 4/10 | Test Accuracy: 91.57% **
# Epoch [5/10], Step [40/89], IRM Loss: 0.6646, SAE Loss: 3.2237
# Epoch [5/10], Step [80/89], IRM Loss: 0.2320, SAE Loss: 3.8896
# ** End of Epoch 5/10 | Test Accuracy: 89.69% **
# Epoch [6/10], Step [40/89], IRM Loss: 0.4437, SAE Loss: 3.5886
# Epoch [6/10], Step [80/89], IRM Loss: 0.1690, SAE Loss: 3.5982
# ** End of Epoch 6/10 | Test Accuracy: 91.45% **
# Epoch [7/10], Step [40/89], IRM Loss: 0.2137, SAE Loss: 3.5408
# Epoch [7/10], Step [80/89], IRM Loss: 0.2672, SAE Loss: 3.3501
# ** End of Epoch 7/10 | Test Accuracy: 90.94% **
# Epoch [8/10], Step [40/89], IRM Loss: 0.2570, SAE Loss: 2.7499
# Epoch [8/10], Step [80/89], IRM Loss: 0.0821, SAE Loss: 3.3892
# ** End of Epoch 8/10 | Test Accuracy: 91.70% **
# Epoch [9/10], Step [40/89], IRM Loss: 0.1135, SAE Loss: 3.4177
# Epoch [9/10], Step [80/89], IRM Loss: 0.0793, SAE Loss: 3.3864
# ** End of Epoch 9/10 | Test Accuracy: 91.57% **
# Epoch [10/10], Step [40/89], IRM Loss: 0.0530, SAE Loss: 3.3021
# Epoch [10/10], Step [80/89], IRM Loss: 0.0824, SAE Loss: 2.5361
# ** End of Epoch 10/10 | Test Accuracy: 91.45% **
# --------------------------------------------

# %% [markdown]
# ##A -> W **DO** **NOT** **RUN**

# %%
lambda_irm_pair = [10.0, 4.0, 0.0]
lambda_sparse=[0.1, 0.1, 0.1]

trained_model_sae_office = train_model_irm_sae_with_warmup_office(
            # model=trained_model_sae_office,
            batch_size=32,
            num_warmup_epochs=4,
            num_main_epochs=10,
            lr=1e-5,
            lr_sae=5e-5,
            lambda_irm=1.0,
            lambda_sae_rec=2.0,
            lambda_sae_sparse=2e-4,
            device='cuda',
            verbose=True,
            lambda_irm_pair=lambda_irm_pair,
            lambda_sparse=lambda_sparse
        )
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/89], IRM Loss: 17.4886, SAE Loss: 36.3434
# Epoch [1/10], Step [80/89], IRM Loss: 16.9284, SAE Loss: 16.5139
# ** End of Epoch 1/10 | Test Accuracy: 16.27% **
# Epoch [2/10], Step [40/89], IRM Loss: 11.7183, SAE Loss: 3.8549
# Epoch [2/10], Step [80/89], IRM Loss: 6.7545, SAE Loss: 4.2968
# ** End of Epoch 2/10 | Test Accuracy: 78.31% **
# Epoch [3/10], Step [40/89], IRM Loss: 2.1402, SAE Loss: 4.0041
# Epoch [3/10], Step [80/89], IRM Loss: 2.5182, SAE Loss: 4.7085
# ** End of Epoch 3/10 | Test Accuracy: 87.95% **
# Epoch [4/10], Step [40/89], IRM Loss: 1.2146, SAE Loss: 4.8893
# Epoch [4/10], Step [80/89], IRM Loss: 2.4019, SAE Loss: 4.2020
# ** End of Epoch 4/10 | Test Accuracy: 89.36% **
# Epoch [5/10], Step [40/89], IRM Loss: 0.5383, SAE Loss: 4.2130
# Epoch [5/10], Step [80/89], IRM Loss: 0.8254, SAE Loss: 4.2853
# ** End of Epoch 5/10 | Test Accuracy: 91.97% **
# Epoch [6/10], Step [40/89], IRM Loss: 0.2088, SAE Loss: 4.9362
# Epoch [6/10], Step [80/89], IRM Loss: 0.2334, SAE Loss: 4.9267
# ** End of Epoch 6/10 | Test Accuracy: 91.97% **
# Epoch [7/10], Step [40/89], IRM Loss: 0.1490, SAE Loss: 4.6180
# Epoch [7/10], Step [80/89], IRM Loss: 0.3141, SAE Loss: 5.2176
# ** End of Epoch 7/10 | Test Accuracy: 91.57% **
# Epoch [8/10], Step [40/89], IRM Loss: 0.1140, SAE Loss: 4.2205
# Epoch [8/10], Step [80/89], IRM Loss: 0.1024, SAE Loss: 4.2127
# ** End of Epoch 8/10 | Test Accuracy: 92.37% **
# Epoch [9/10], Step [40/89], IRM Loss: 0.0712, SAE Loss: 4.7058
# Epoch [9/10], Step [80/89], IRM Loss: 0.1467, SAE Loss: 4.7731
# ** End of Epoch 9/10 | Test Accuracy: 92.17% **
# Epoch [10/10], Step [40/89], IRM Loss: 0.0793, SAE Loss: 4.3806
# Epoch [10/10], Step [80/89], IRM Loss: 0.0563, SAE Loss: 4.1882
# ** End of Epoch 10/10 | Test Accuracy: 92.97% **

# %% [markdown]
# ##W -> A **DO** **NOT** **RUN**

# %%
combination = ["W", "A"]
print(f"------------Combination: {combination}--------------")
lambda_irm_pair = [10.0, 4.0, 0.0]
lambda_sparse=[0.1, 0.1, 0.1]

trained_model_sae_office = train_model_irm_sae_with_warmup_office(
            # model=trained_model_sae_office,
            batch_size=32,
            num_warmup_epochs=4,
            num_main_epochs=10,
            lr=1e-5,
            lr_sae=5e-5,
            lambda_irm=1.0,
            lambda_sae_rec=2.0,
            lambda_sae_sparse=2e-4,
            device='cuda',
            verbose=True,
            lambda_irm_pair=lambda_irm_pair,
            lambda_sparse=lambda_sparse,
            loader=combination
        )

print("--------------------------------------------")
# Out:
# ------------Combination: ['W', 'A']--------------
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# ===== Main Phase (IRM + SAE) =====
# ** End of Epoch 1/10 | Test Accuracy: 3.55% **
# ** End of Epoch 2/10 | Test Accuracy: 3.80% **
# ** End of Epoch 3/10 | Test Accuracy: 17.78% **
# ** End of Epoch 4/10 | Test Accuracy: 12.64% **
# ** End of Epoch 5/10 | Test Accuracy: 11.61% **
# ** End of Epoch 6/10 | Test Accuracy: 18.14% **
# ** End of Epoch 7/10 | Test Accuracy: 39.58% **
# ** End of Epoch 8/10 | Test Accuracy: 62.62% **
# ** End of Epoch 9/10 | Test Accuracy: 74.19% **
# ** End of Epoch 10/10 | Test Accuracy: 76.93% **
# --------------------------------------------

# %% [markdown]
# ## W -> D **DO** **NOT** **RUN**

# %%
combination = ["W", "D"]
print(f"------------Combination: {combination}--------------")
lambda_irm_pair = [10.0, 4.0, 0.0]
lambda_sparse=[0.1, 0.1, 0.1]

trained_model_sae_office = train_model_irm_sae_with_warmup_office(
            # model=trained_model_sae_office,
            batch_size=32,
            num_warmup_epochs=4,
            num_main_epochs=10,
            lr=1e-5,
            lr_sae=5e-5,
            lambda_irm=1.0,
            lambda_sae_rec=2.0,
            lambda_sae_sparse=2e-4,
            device='cuda',
            verbose=True,
            lambda_irm_pair=lambda_irm_pair,
            lambda_sparse=lambda_sparse,
            loader=combination
        )

print("--------------------------------------------")
# Out:
# ------------Combination: ['W', 'D']--------------
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# ===== Main Phase (IRM + SAE) =====
# ** End of Epoch 1/10 | Test Accuracy: 3.77% **
# ** End of Epoch 2/10 | Test Accuracy: 5.79% **
# ** End of Epoch 3/10 | Test Accuracy: 19.25% **
# ** End of Epoch 4/10 | Test Accuracy: 21.13% **
# ** End of Epoch 5/10 | Test Accuracy: 30.69% **
# ** End of Epoch 6/10 | Test Accuracy: 47.30% **
# ** End of Epoch 7/10 | Test Accuracy: 68.81% **
# ** End of Epoch 8/10 | Test Accuracy: 89.81% **
# ** End of Epoch 9/10 | Test Accuracy: 98.36% **
# ** End of Epoch 10/10 | Test Accuracy: 98.99% **
# --------------------------------------------

# %% [markdown]
# ## D -> W **DO** **NOT** **RUN**

# %%
combination = ["D", "W"]
print(f"------------Combination: {combination}--------------")
lambda_irm_pair = [10.0, 4.0, 0.0]
lambda_sparse=[0.1, 0.1, 0.1]

trained_model_sae_office = train_model_irm_sae_with_warmup_office(
            # model=trained_model_sae_office,
            batch_size=32,
            num_warmup_epochs=4,
            num_main_epochs=10,
            lr=1e-5,
            lr_sae=5e-5,
            lambda_irm=1.0,
            lambda_sae_rec=2.0,
            lambda_sae_sparse=2e-4,
            device='cuda',
            verbose=True,
            lambda_irm_pair=lambda_irm_pair,
            lambda_sparse=lambda_sparse,
            loader=combination
        )

print("--------------------------------------------")
# Out:
# ------------Combination: ['D', 'W']--------------
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# ===== Main Phase (IRM + SAE) =====
# ** End of Epoch 1/10 | Test Accuracy: 4.62% **
# ** End of Epoch 2/10 | Test Accuracy: 22.49% **
# ** End of Epoch 3/10 | Test Accuracy: 32.13% **
# ** End of Epoch 4/10 | Test Accuracy: 42.77% **
# ** End of Epoch 5/10 | Test Accuracy: 81.93% **
# ** End of Epoch 6/10 | Test Accuracy: 98.19% **
# ** End of Epoch 7/10 | Test Accuracy: 99.00% **
# ** End of Epoch 8/10 | Test Accuracy: 99.40% **
# ** End of Epoch 9/10 | Test Accuracy: 99.60% **
# ** End of Epoch 10/10 | Test Accuracy: 99.60% **
# --------------------------------------------

# %% [markdown]
# ## D -> A **DO** **NOT** **RUN**

# %%
combination = ["D", "A"]
print(f"------------Combination: {combination}--------------")
lambda_irm_pair = [10.0, 4.0, 0.0]
lambda_sparse=[0.1, 0.1, 0.1]

trained_model_sae_office = train_model_irm_sae_with_warmup_office(
            # model=trained_model_sae_office,
            batch_size=32,
            num_warmup_epochs=4,
            num_main_epochs=10,
            lr=1e-5,
            lr_sae=5e-5,
            lambda_irm=1.0,
            lambda_sae_rec=2.0,
            lambda_sae_sparse=2e-4,
            device='cuda',
            verbose=True,
            lambda_irm_pair=lambda_irm_pair,
            lambda_sparse=lambda_sparse,
            loader=combination
        )

print("--------------------------------------------")
# Out:
# ------------Combination: ['D', 'A']--------------
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# ===== Main Phase (IRM + SAE) =====
# ** End of Epoch 2/10 | Test Accuracy: 9.16% **
# ** End of Epoch 3/10 | Test Accuracy: 7.24% **
# ** End of Epoch 4/10 | Test Accuracy: 19.38% **
# ** End of Epoch 5/10 | Test Accuracy: 42.28% **
# ** End of Epoch 6/10 | Test Accuracy: 69.76% **
# ** End of Epoch 7/10 | Test Accuracy: 76.11% **
# ** End of Epoch 8/10 | Test Accuracy: 77.17% **
# ** End of Epoch 9/10 | Test Accuracy: 77.64% **
# ** End of Epoch 10/10 | Test Accuracy: 77.64% **
# --------------------------------------------

# %% [markdown]
# ## Base Vit accuracies

# %%
from torchvision.models import swin_b
from tqdm.notebook import tqdm

def get_base_accuracy(loader=None):

    # print(f"------------Combination: {loader}--------------")

    loader_art, loader_clp, loader_prod, loader_irl = get_office_data_loaders(32)

    source, target = loader if loader is not None else ['A', 'C']

    if source == 'A':
        loader_source = loader_art
    elif source == 'C':
        loader_source = loader_clp
    elif source == 'P':
        loader_source = loader_prod
    elif source == 'R':
        loader_source = loader_irl

    if target == 'A':
        loader_target = loader_art
    elif target == 'C':
        loader_target = loader_clp
    elif target == 'P':
        loader_target = loader_prod
    elif target == 'R':
        loader_target = loader_irl


    model = swin_b(weights='IMAGENET1K_V1')
    model.head = nn.Linear(1024, 65)
    model = model.to("cuda")

    optm = torch.optim.Adam(model.parameters(), lr=5e-5)
    epochs = 10

    for epoch in range(epochs):
        model.train()
        for x, y in (loader_source):
            x, y = x.to("cuda"), y.to("cuda")

            optm.zero_grad()
            logits = model(x)
            loss = F.cross_entropy(logits, y)
            loss.backward()
            optm.step()

        print(f"Epoch: {epoch+1}/{epochs} | Loss: {loss.item()}")

        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for x, y in (loader_target):
                x, y = x.to("cuda"), y.to("cuda")

                logits = model(x)
                preds = torch.argmax(logits, dim=1)
                correct += (preds == y).sum().item()
                total += y.size(0)
        acc = 100.0 * correct / total
        print(f"Epoch: {epoch+1}/{epochs} | Test Accuracy: {acc}")

        # print("--------------------------------------------")

# %%
combinations = [["A", "C"], ["A", "P"], ["A", "R"], ["C", "P"], ["C", "R"], ["C", "A"], ["P", "R"], ["P", "A"], ["P", "C"], ["R", "A"], ["R", "C"], ["R", "P"]]

for combination in combinations:
    print(f"------------Combination: {combination}--------------")
    get_base_accuracy(loader=combination)
    print("--------------------------------------------")
# Out:
# ------------Combination: ['A', 'C']--------------
# Downloading: "https://download.pytorch.org/models/swin_b-68c6b09e.pth" to /root/.cache/torch/hub/checkpoints/swin_b-68c6b09e.pth
# 100%|██████████| 335M/335M [00:02<00:00, 161MB/s]
# Epoch: 1/10 | Loss: 2.612029552459717
# Epoch: 1/10 | Test Accuracy: 33.585337915234824
# Epoch: 2/10 | Loss: 0.7936190962791443
# Epoch: 2/10 | Test Accuracy: 48.24742268041237
# Epoch: 3/10 | Loss: 0.5184156894683838
# Epoch: 3/10 | Test Accuracy: 52.96678121420389
# Epoch: 4/10 | Loss: 0.4112170934677124
# Epoch: 4/10 | Test Accuracy: 52.485681557846505
# Epoch: 5/10 | Loss: 0.20589110255241394
# Epoch: 5/10 | Test Accuracy: 53.83734249713631
# Epoch: 6/10 | Loss: 0.1458369940519333
# Epoch: 6/10 | Test Accuracy: 54.47880870561283
# Epoch: 7/10 | Loss: 0.11391185969114304
# Epoch: 7/10 | Test Accuracy: 55.18900343642612
# Epoch: 8/10 | Loss: 0.12304243445396423
# Epoch: 8/10 | Test Accuracy: 54.38717067583047
# Epoch: 9/10 | Loss: 0.015888936817646027
# Epoch: 9/10 | Test Accuracy: 55.32646048109966
# Epoch: 10/10 | Loss: 0.0335274264216423
# Epoch: 10/10 | Test Accuracy: 55.37227949599084
# --------------------------------------------
# ------------Combination: ['A', 'P']--------------
# Epoch: 1/10 | Loss: 2.606938123703003
# Epoch: 1/10 | Test Accuracy: 41.47330479837801
# Epoch: 2/10 | Loss: 1.3873263597488403
# Epoch: 2/10 | Test Accuracy: 65.91574678981753
# Epoch: 3/10 | Loss: 0.6679617762565613
# Epoch: 3/10 | Test Accuracy: 71.07456634377112
# Epoch: 4/10 | Loss: 0.3385370075702667
# Epoch: 4/10 | Test Accuracy: 74.43117819328678
# Epoch: 5/10 | Loss: 0.1261875033378601
# Epoch: 5/10 | Test Accuracy: 75.10700608245101
# Epoch: 6/10 | Loss: 0.23039406538009644
# Epoch: 6/10 | Test Accuracy: 74.43117819328678
# Epoch: 7/10 | Loss: 0.08397459983825684
# Epoch: 7/10 | Test Accuracy: 73.2822707817076
# Epoch: 8/10 | Loss: 0.12619425356388092
# Epoch: 8/10 | Test Accuracy: 74.88173011939627
# Epoch: 9/10 | Loss: 0.030758142471313477
# Epoch: 9/10 | Test Accuracy: 75.82788916422618
# Epoch: 10/10 | Loss: 0.17440956830978394
# Epoch: 10/10 | Test Accuracy: 75.51250281594953
# --------------------------------------------
# ------------Combination: ['A', 'R']--------------
# Epoch: 1/10 | Loss: 2.5552899837493896
# Epoch: 1/10 | Test Accuracy: 47.11957769107184
# Epoch: 2/10 | Loss: 1.109113097190857
# Epoch: 2/10 | Test Accuracy: 71.67775992655497
# Epoch: 3/10 | Loss: 0.47593456506729126
# Epoch: 3/10 | Test Accuracy: 78.12715170989213
# Epoch: 4/10 | Loss: 0.5600082874298096
# Epoch: 4/10 | Test Accuracy: 79.8714711957769
# Epoch: 5/10 | Loss: 0.159316286444664
# Epoch: 5/10 | Test Accuracy: 80.16984163415194
# Epoch: 6/10 | Loss: 0.09832142293453217
# Epoch: 6/10 | Test Accuracy: 80.69772779435391
# Epoch: 7/10 | Loss: 0.21515578031539917
# Epoch: 7/10 | Test Accuracy: 80.46821207252697
# Epoch: 8/10 | Loss: 0.0754348412156105
# Epoch: 8/10 | Test Accuracy: 81.52398439293091
# Epoch: 9/10 | Loss: 0.02427452616393566
# Epoch: 9/10 | Test Accuracy: 81.15675923800781
# Epoch: 10/10 | Loss: 0.14360739290714264
# Epoch: 10/10 | Test Accuracy: 81.68464539820978
# --------------------------------------------
# ------------Combination: ['C', 'P']--------------
# Epoch: 1/10 | Loss: 2.129020929336548
# Epoch: 1/10 | Test Accuracy: 61.00473079522415
# Epoch: 2/10 | Loss: 1.136049747467041
# Epoch: 2/10 | Test Accuracy: 71.20973192160396
# Epoch: 3/10 | Loss: 0.6139984726905823
# Epoch: 3/10 | Test Accuracy: 73.2822707817076
# Epoch: 4/10 | Loss: 0.14022989571094513
# Epoch: 4/10 | Test Accuracy: 73.8004054967335
# Epoch: 5/10 | Loss: 0.3127438724040985
# Epoch: 5/10 | Test Accuracy: 73.93557107456634
# Epoch: 6/10 | Loss: 0.19242209196090698
# Epoch: 6/10 | Test Accuracy: 74.54381617481415
# Epoch: 7/10 | Loss: 0.24992449581623077
# Epoch: 7/10 | Test Accuracy: 72.96688443343095
# Epoch: 8/10 | Loss: 0.03343508020043373
# Epoch: 8/10 | Test Accuracy: 75.71525118269881
# Epoch: 9/10 | Loss: 0.12037400901317596
# Epoch: 9/10 | Test Accuracy: 74.67898175264699
# Epoch: 10/10 | Loss: 0.41588708758354187
# Epoch: 10/10 | Test Accuracy: 74.16084703762108
# --------------------------------------------
# ------------Combination: ['C', 'R']--------------
# Epoch: 1/10 | Loss: 2.21219801902771
# Epoch: 1/10 | Test Accuracy: 61.87743860454441
# Epoch: 2/10 | Loss: 0.7566699385643005
# Epoch: 2/10 | Test Accuracy: 71.72366307092035
# Epoch: 3/10 | Loss: 0.4975450932979584
# Epoch: 3/10 | Test Accuracy: 74.73031902685334
# Epoch: 4/10 | Loss: 0.1293061226606369
# Epoch: 4/10 | Test Accuracy: 75.67133348634381
# Epoch: 5/10 | Loss: 0.10941331088542938
# Epoch: 5/10 | Test Accuracy: 76.33692907964196
# Epoch: 6/10 | Loss: 0.24828965961933136
# Epoch: 6/10 | Test Accuracy: 75.48772090888225
# Epoch: 7/10 | Loss: 0.026612678542733192
# Epoch: 7/10 | Test Accuracy: 76.107413357815
# Epoch: 8/10 | Loss: 0.21914805471897125
# Epoch: 8/10 | Test Accuracy: 77.27794353913244
# Epoch: 9/10 | Loss: 0.014807069674134254
# Epoch: 9/10 | Test Accuracy: 75.39591462015149
# Epoch: 10/10 | Loss: 0.07159844040870667
# Epoch: 10/10 | Test Accuracy: 76.08446178563231
# --------------------------------------------
# ------------Combination: ['C', 'A']--------------
# Epoch: 1/10 | Loss: 1.1496477127075195
# Epoch: 1/10 | Test Accuracy: 58.26122785331685
# Epoch: 2/10 | Loss: 0.5237921476364136
# Epoch: 2/10 | Test Accuracy: 66.74907292954265
# Epoch: 3/10 | Loss: 0.10394136607646942
# Epoch: 3/10 | Test Accuracy: 69.13885455294603
# Epoch: 4/10 | Loss: 0.26821839809417725
# Epoch: 4/10 | Test Accuracy: 70.25133910177173
# Epoch: 5/10 | Loss: 0.2026793360710144
# Epoch: 5/10 | Test Accuracy: 71.77585496497734
# Epoch: 6/10 | Loss: 0.1317981630563736
# Epoch: 6/10 | Test Accuracy: 70.49855789039967
# Epoch: 7/10 | Loss: 0.18881358206272125
# Epoch: 7/10 | Test Accuracy: 70.04532344458178
# Epoch: 8/10 | Loss: 0.037992898374795914
# Epoch: 8/10 | Test Accuracy: 69.83930778739185
# Epoch: 9/10 | Loss: 0.009719028137624264
# Epoch: 9/10 | Test Accuracy: 71.07540173053152
# Epoch: 10/10 | Loss: 0.2173311561346054
# Epoch: 10/10 | Test Accuracy: 70.82818294190359
# --------------------------------------------
# ------------Combination: ['P', 'R']--------------
# Epoch: 1/10 | Loss: 0.6114957332611084
# Epoch: 1/10 | Test Accuracy: 76.06151021344962
# Epoch: 2/10 | Loss: 0.18104946613311768
# Epoch: 2/10 | Test Accuracy: 80.03213220105577
# Epoch: 3/10 | Loss: 0.19979465007781982
# Epoch: 3/10 | Test Accuracy: 81.08790452145972
# Epoch: 4/10 | Loss: 0.06255786865949631
# Epoch: 4/10 | Test Accuracy: 82.0059674087675
# Epoch: 5/10 | Loss: 0.00892643816769123
# Epoch: 5/10 | Test Accuracy: 80.766582510902
# Epoch: 6/10 | Loss: 0.07887136191129684
# Epoch: 6/10 | Test Accuracy: 81.89120954785403
# Epoch: 7/10 | Loss: 0.08213623613119125
# Epoch: 7/10 | Test Accuracy: 81.592839109479
# Epoch: 8/10 | Loss: 0.007321925368160009
# Epoch: 8/10 | Test Accuracy: 82.51090199678679
# Epoch: 9/10 | Loss: 0.01963849365711212
# Epoch: 9/10 | Test Accuracy: 82.23548313059445
# Epoch: 10/10 | Loss: 0.005236535333096981
# Epoch: 10/10 | Test Accuracy: 80.62887307780584
# --------------------------------------------
# ------------Combination: ['P', 'A']--------------
# Epoch: 1/10 | Loss: 0.9249494075775146
# Epoch: 1/10 | Test Accuracy: 61.68108776266996
# Epoch: 2/10 | Loss: 0.29608353972435
# Epoch: 2/10 | Test Accuracy: 65.7601977750309
# Epoch: 3/10 | Loss: 0.12136700004339218
# Epoch: 3/10 | Test Accuracy: 66.29583848372476
# Epoch: 4/10 | Loss: 0.03888394683599472
# Epoch: 4/10 | Test Accuracy: 66.5430572723527
# Epoch: 5/10 | Loss: 0.027986835688352585
# Epoch: 5/10 | Test Accuracy: 65.7601977750309
# Epoch: 6/10 | Loss: 0.04111841320991516
# Epoch: 6/10 | Test Accuracy: 66.37824474660074
# Epoch: 7/10 | Loss: 0.007093616295605898
# Epoch: 7/10 | Test Accuracy: 65.55418211784095
# Epoch: 8/10 | Loss: 0.05830264091491699
# Epoch: 8/10 | Test Accuracy: 65.80140090646888
# Epoch: 9/10 | Loss: 0.05056795850396156
# Epoch: 9/10 | Test Accuracy: 65.47177585496497
# Epoch: 10/10 | Loss: 0.00907472986727953
# Epoch: 10/10 | Test Accuracy: 67.90276060980635
# --------------------------------------------
# ------------Combination: ['P', 'C']--------------
# Epoch: 1/10 | Loss: 0.33251532912254333
# Epoch: 1/10 | Test Accuracy: 45.49828178694158
# Epoch: 2/10 | Loss: 0.20328961312770844
# Epoch: 2/10 | Test Accuracy: 48.65979381443299
# Epoch: 3/10 | Loss: 0.19278749823570251
# Epoch: 3/10 | Test Accuracy: 50.76746849942726
# Epoch: 4/10 | Loss: 0.04079212620854378
# Epoch: 4/10 | Test Accuracy: 47.90378006872852
# Epoch: 5/10 | Loss: 0.06196078658103943
# Epoch: 5/10 | Test Accuracy: 49.851088201603666
# Epoch: 6/10 | Loss: 0.06714532524347305
# Epoch: 6/10 | Test Accuracy: 48.20160366552119
# Epoch: 7/10 | Loss: 0.04867076873779297
# Epoch: 7/10 | Test Accuracy: 48.980526918671245
# Epoch: 8/10 | Loss: 0.014747990295290947
# Epoch: 8/10 | Test Accuracy: 49.16380297823597
# Epoch: 9/10 | Loss: 0.004703018814325333
# Epoch: 9/10 | Test Accuracy: 49.805269186712486
# Epoch: 10/10 | Loss: 0.009500506334006786
# Epoch: 10/10 | Test Accuracy: 48.27033218785796
# --------------------------------------------
# ------------Combination: ['R', 'A']--------------
# Epoch: 1/10 | Loss: 0.3434811234474182
# Epoch: 1/10 | Test Accuracy: 68.43840131850021
# Epoch: 2/10 | Loss: 0.22139497101306915
# Epoch: 2/10 | Test Accuracy: 71.24021425628348
# Epoch: 3/10 | Loss: 0.17843849956989288
# Epoch: 3/10 | Test Accuracy: 71.52863617634941
# Epoch: 4/10 | Loss: 0.004242639988660812
# Epoch: 4/10 | Test Accuracy: 74.2480428512567
# Epoch: 5/10 | Loss: 0.18515700101852417
# Epoch: 5/10 | Test Accuracy: 74.45405850844664
# Epoch: 6/10 | Loss: 0.3204213082790375
# Epoch: 6/10 | Test Accuracy: 74.28924598269468
# Epoch: 7/10 | Loss: 0.08141396939754486
# Epoch: 7/10 | Test Accuracy: 72.10548001648125
# Epoch: 8/10 | Loss: 0.026218339800834656
# Epoch: 8/10 | Test Accuracy: 75.81376184590029
# Epoch: 9/10 | Loss: 0.003878932446241379
# Epoch: 9/10 | Test Accuracy: 73.01194890811702
# Epoch: 10/10 | Loss: 0.0240815170109272
# Epoch: 10/10 | Test Accuracy: 73.95962093119077
# --------------------------------------------
# ------------Combination: ['R', 'C']--------------
# Epoch: 1/10 | Loss: 0.5265167951583862
# Epoch: 1/10 | Test Accuracy: 49.50744558991982
# Epoch: 2/10 | Loss: 0.3224601149559021
# Epoch: 2/10 | Test Accuracy: 54.20389461626575
# Epoch: 3/10 | Loss: 0.0983213484287262
# Epoch: 3/10 | Test Accuracy: 55.715922107674686
# Epoch: 4/10 | Loss: 0.057678915560245514
# Epoch: 4/10 | Test Accuracy: 54.753722794959906
# Epoch: 5/10 | Loss: 0.0279521606862545
# Epoch: 5/10 | Test Accuracy: 53.516609392898054
# Epoch: 6/10 | Loss: 0.050522513687610626
# Epoch: 6/10 | Test Accuracy: 52.64604810996563
# Epoch: 7/10 | Loss: 0.008321152068674564
# Epoch: 7/10 | Test Accuracy: 51.66093928980527
# Epoch: 8/10 | Loss: 0.06150240823626518
# Epoch: 8/10 | Test Accuracy: 53.01260022909508
# Epoch: 9/10 | Loss: 0.1573205292224884
# Epoch: 9/10 | Test Accuracy: 51.98167239404353
# Epoch: 10/10 | Loss: 0.012440365739166737
# Epoch: 10/10 | Test Accuracy: 52.73768613974799
# --------------------------------------------
# ------------Combination: ['R', 'P']--------------
# Epoch: 1/10 | Loss: 1.7081215381622314
# Epoch: 1/10 | Test Accuracy: 78.23834196891191
# Epoch: 2/10 | Loss: 0.17394281923770905
# Epoch: 2/10 | Test Accuracy: 83.21694075242172
# Epoch: 3/10 | Loss: 0.04358535632491112
# Epoch: 3/10 | Test Accuracy: 83.82518585266952
# Epoch: 4/10 | Loss: 0.09895574301481247
# Epoch: 4/10 | Test Accuracy: 83.96035143050237
# Epoch: 5/10 | Loss: 0.013420367613434792
# Epoch: 5/10 | Test Accuracy: 83.69002027483667
# Epoch: 6/10 | Loss: 0.0024782319087535143
# Epoch: 6/10 | Test Accuracy: 85.55981076819103
# Epoch: 7/10 | Loss: 0.061459980905056
# Epoch: 7/10 | Test Accuracy: 85.35706240144177
# Epoch: 8/10 | Loss: 0.05526099354028702
# Epoch: 8/10 | Test Accuracy: 85.46970038296914
# Epoch: 9/10 | Loss: 0.006472430191934109
# Epoch: 9/10 | Test Accuracy: 84.20815498986258
# Epoch: 10/10 | Loss: 0.006469460669904947
# Epoch: 10/10 | Test Accuracy: 84.95156566794323
# --------------------------------------------

# %%
# reverse the combination list
combinations_reverse = combinations[::-1]

# %%
for combination in combinations_reverse:
    print(f"------------Combination: {combination}--------------")
    lambda_irm_pair = [10.0, 4.0, 0.0]
    lambda_sparse=[0.1, 0.1, 0.1]

    trained_model_sae_office = train_model_irm_sae_with_warmup_office(
                # model=trained_model_sae_office,
                batch_size=32,
                num_warmup_epochs=4,
                num_main_epochs=10,
                lr=1e-5,
                lr_sae=5e-5,
                lambda_irm=1.0,
                lambda_sae_rec=2.0,
                lambda_sae_sparse=2e-4,
                device='cuda',
                verbose=True,
                lambda_irm_pair=lambda_irm_pair,
                lambda_sparse=lambda_sparse,
                loader=combination
            )
    print("--------------------------------------------")
# Out:
# ------------Combination: ['R', 'P']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/137], IRM Loss: 20.8602, SAE Loss: 42.1482
# Epoch [1/10], Step [80/137], IRM Loss: 20.8675, SAE Loss: 29.3719
# Epoch [1/10], Step [120/137], IRM Loss: 20.4721, SAE Loss: 15.5660
# ** End of Epoch 1/10 | Test Accuracy: 6.71% **
# Epoch [2/10], Step [40/137], IRM Loss: 17.8856, SAE Loss: 5.5534
# Epoch [2/10], Step [80/137], IRM Loss: 15.1471, SAE Loss: 4.4189
# Epoch [2/10], Step [120/137], IRM Loss: 11.7534, SAE Loss: 4.0728
# ** End of Epoch 2/10 | Test Accuracy: 33.79% **
# Epoch [3/10], Step [40/137], IRM Loss: 7.1011, SAE Loss: 4.8947
# Epoch [3/10], Step [80/137], IRM Loss: 5.1481, SAE Loss: 5.3344
# Epoch [3/10], Step [120/137], IRM Loss: 4.6132, SAE Loss: 4.0294
# ** End of Epoch 3/10 | Test Accuracy: 79.91% **
# Epoch [4/10], Step [40/137], IRM Loss: 1.9871, SAE Loss: 4.6532
# Epoch [4/10], Step [80/137], IRM Loss: 2.7737, SAE Loss: 4.7461
# Epoch [4/10], Step [120/137], IRM Loss: 1.2253, SAE Loss: 5.1073
# ** End of Epoch 4/10 | Test Accuracy: 87.34% **
# Epoch [5/10], Step [40/137], IRM Loss: 0.7747, SAE Loss: 5.9482
# Epoch [5/10], Step [80/137], IRM Loss: 0.6438, SAE Loss: 5.7359
# Epoch [5/10], Step [120/137], IRM Loss: 0.7576, SAE Loss: 4.5767
# ** End of Epoch 5/10 | Test Accuracy: 88.80% **
# Epoch [6/10], Step [40/137], IRM Loss: 0.2602, SAE Loss: 5.3653
# Epoch [6/10], Step [80/137], IRM Loss: 0.6616, SAE Loss: 5.1894
# Epoch [6/10], Step [120/137], IRM Loss: 0.2831, SAE Loss: 4.9337
# ** End of Epoch 6/10 | Test Accuracy: 89.32% **
# Epoch [7/10], Step [40/137], IRM Loss: 0.8006, SAE Loss: 4.8629
# Epoch [7/10], Step [80/137], IRM Loss: 0.7932, SAE Loss: 4.9310
# Epoch [7/10], Step [120/137], IRM Loss: 0.1593, SAE Loss: 5.6015
# ** End of Epoch 7/10 | Test Accuracy: 89.16% **
# Epoch [8/10], Step [40/137], IRM Loss: 0.5066, SAE Loss: 4.6221
# Epoch [8/10], Step [80/137], IRM Loss: 0.2266, SAE Loss: 5.1980
# Epoch [8/10], Step [120/137], IRM Loss: 0.1225, SAE Loss: 5.0955
# ** End of Epoch 8/10 | Test Accuracy: 88.74% **
# Epoch [9/10], Step [40/137], IRM Loss: 0.2614, SAE Loss: 4.8934
# Epoch [9/10], Step [80/137], IRM Loss: 1.1716, SAE Loss: 5.1233
# Epoch [9/10], Step [120/137], IRM Loss: 0.0915, SAE Loss: 4.5530
# ** End of Epoch 9/10 | Test Accuracy: 88.40% **
# Epoch [10/10], Step [40/137], IRM Loss: 0.3127, SAE Loss: 4.5196
# Epoch [10/10], Step [80/137], IRM Loss: 0.3643, SAE Loss: 4.4954
# Epoch [10/10], Step [120/137], IRM Loss: 0.6443, SAE Loss: 4.6448
# ** End of Epoch 10/10 | Test Accuracy: 88.74% **
# --------------------------------------------
# ------------Combination: ['R', 'C']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/137], IRM Loss: 20.9741, SAE Loss: 37.5250
# Epoch [1/10], Step [80/137], IRM Loss: 21.4449, SAE Loss: 23.7197
# Epoch [1/10], Step [120/137], IRM Loss: 20.3468, SAE Loss: 9.6595
# ** End of Epoch 1/10 | Test Accuracy: 11.52% **
# Epoch [2/10], Step [40/137], IRM Loss: 17.0623, SAE Loss: 5.3949
# Epoch [2/10], Step [80/137], IRM Loss: 15.2526, SAE Loss: 4.4744
# Epoch [2/10], Step [120/137], IRM Loss: 11.0166, SAE Loss: 5.5201
# ** End of Epoch 2/10 | Test Accuracy: 33.06% **
# Epoch [3/10], Step [40/137], IRM Loss: 7.6497, SAE Loss: 5.1521
# Epoch [3/10], Step [80/137], IRM Loss: 3.8334, SAE Loss: 5.8253
# Epoch [3/10], Step [120/137], IRM Loss: 4.4397, SAE Loss: 6.2335
# ** End of Epoch 3/10 | Test Accuracy: 59.11% **
# Epoch [4/10], Step [40/137], IRM Loss: 1.9464, SAE Loss: 5.9734
# Epoch [4/10], Step [80/137], IRM Loss: 2.1528, SAE Loss: 6.9063
# Epoch [4/10], Step [120/137], IRM Loss: 1.2489, SAE Loss: 7.1325
# ** End of Epoch 4/10 | Test Accuracy: 67.84% **
# Epoch [5/10], Step [40/137], IRM Loss: 1.2785, SAE Loss: 7.2758
# Epoch [5/10], Step [80/137], IRM Loss: 0.7733, SAE Loss: 5.8493
# Epoch [5/10], Step [120/137], IRM Loss: 0.7733, SAE Loss: 5.9113
# ** End of Epoch 5/10 | Test Accuracy: 69.44% **
# Epoch [6/10], Step [40/137], IRM Loss: 0.2394, SAE Loss: 6.8417
# Epoch [6/10], Step [80/137], IRM Loss: 0.2983, SAE Loss: 6.8502
# Epoch [6/10], Step [120/137], IRM Loss: 0.9427, SAE Loss: 5.8905
# ** End of Epoch 6/10 | Test Accuracy: 68.32% **
# Epoch [7/10], Step [40/137], IRM Loss: 0.3265, SAE Loss: 6.1616
# Epoch [7/10], Step [80/137], IRM Loss: 0.1394, SAE Loss: 7.1515
# Epoch [7/10], Step [120/137], IRM Loss: 0.3980, SAE Loss: 6.0091
# ** End of Epoch 7/10 | Test Accuracy: 68.18% **
# Epoch [8/10], Step [40/137], IRM Loss: 0.1436, SAE Loss: 5.2765
# Epoch [8/10], Step [80/137], IRM Loss: 0.1580, SAE Loss: 6.0184
# Epoch [8/10], Step [120/137], IRM Loss: 0.1316, SAE Loss: 6.7526
# ** End of Epoch 8/10 | Test Accuracy: 67.40% **
# Epoch [9/10], Step [40/137], IRM Loss: 0.1447, SAE Loss: 5.2522
# Epoch [9/10], Step [80/137], IRM Loss: 0.0919, SAE Loss: 5.5731
# Epoch [9/10], Step [120/137], IRM Loss: 0.1176, SAE Loss: 5.2765
# ** End of Epoch 9/10 | Test Accuracy: 66.74% **
# Epoch [10/10], Step [40/137], IRM Loss: 0.2836, SAE Loss: 4.9558
# Epoch [10/10], Step [80/137], IRM Loss: 0.0767, SAE Loss: 6.6525
# Epoch [10/10], Step [120/137], IRM Loss: 0.3697, SAE Loss: 6.7877
# ** End of Epoch 10/10 | Test Accuracy: 69.23% **
# --------------------------------------------
# ------------Combination: ['R', 'A']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/137], IRM Loss: 20.8187, SAE Loss: 34.0292
# Epoch [1/10], Step [80/137], IRM Loss: 20.5735, SAE Loss: 28.1566
# Epoch [1/10], Step [120/137], IRM Loss: 20.2606, SAE Loss: 13.8555
# ** End of Epoch 1/10 | Test Accuracy: 13.97% **
# Epoch [2/10], Step [40/137], IRM Loss: 17.9604, SAE Loss: 4.2361
# Epoch [2/10], Step [80/137], IRM Loss: 13.7549, SAE Loss: 4.1799
# Epoch [2/10], Step [120/137], IRM Loss: 11.9234, SAE Loss: 5.9261
# ** End of Epoch 2/10 | Test Accuracy: 50.72% **
# Epoch [3/10], Step [40/137], IRM Loss: 5.1778, SAE Loss: 4.6198
# Epoch [3/10], Step [80/137], IRM Loss: 4.5392, SAE Loss: 4.8341
# Epoch [3/10], Step [120/137], IRM Loss: 3.6066, SAE Loss: 5.2414
# ** End of Epoch 3/10 | Test Accuracy: 75.65% **
# Epoch [4/10], Step [40/137], IRM Loss: 0.9790, SAE Loss: 6.1431
# Epoch [4/10], Step [80/137], IRM Loss: 0.7825, SAE Loss: 6.7916
# Epoch [4/10], Step [120/137], IRM Loss: 0.7888, SAE Loss: 6.5783
# ** End of Epoch 4/10 | Test Accuracy: 80.47% **
# Epoch [5/10], Step [40/137], IRM Loss: 1.4391, SAE Loss: 5.5342
# Epoch [5/10], Step [80/137], IRM Loss: 0.9293, SAE Loss: 7.1040
# Epoch [5/10], Step [120/137], IRM Loss: 0.4516, SAE Loss: 5.7444
# ** End of Epoch 5/10 | Test Accuracy: 81.95% **
# Epoch [6/10], Step [40/137], IRM Loss: 0.2239, SAE Loss: 5.7608
# Epoch [6/10], Step [80/137], IRM Loss: 0.2523, SAE Loss: 5.7739
# Epoch [6/10], Step [120/137], IRM Loss: 0.7164, SAE Loss: 5.0617
# ** End of Epoch 6/10 | Test Accuracy: 79.85% **
# Epoch [7/10], Step [40/137], IRM Loss: 0.2480, SAE Loss: 5.3843
# Epoch [7/10], Step [80/137], IRM Loss: 0.2473, SAE Loss: 6.4225
# Epoch [7/10], Step [120/137], IRM Loss: 0.2040, SAE Loss: 5.5520
# ** End of Epoch 7/10 | Test Accuracy: 80.06% **
# Epoch [8/10], Step [40/137], IRM Loss: 0.2416, SAE Loss: 4.1826
# Epoch [8/10], Step [80/137], IRM Loss: 0.3753, SAE Loss: 4.2939
# Epoch [8/10], Step [120/137], IRM Loss: 0.1431, SAE Loss: 5.0826
# ** End of Epoch 8/10 | Test Accuracy: 78.86% **
# Epoch [9/10], Step [40/137], IRM Loss: 0.1303, SAE Loss: 5.3671
# Epoch [9/10], Step [80/137], IRM Loss: 0.1658, SAE Loss: 5.5239
# Epoch [9/10], Step [120/137], IRM Loss: 0.1051, SAE Loss: 4.8641
# ** End of Epoch 9/10 | Test Accuracy: 80.55% **
# Epoch [10/10], Step [40/137], IRM Loss: 0.0959, SAE Loss: 4.1548
# Epoch [10/10], Step [80/137], IRM Loss: 0.0835, SAE Loss: 4.4277
# Epoch [10/10], Step [120/137], IRM Loss: 0.1436, SAE Loss: 5.7819
# ** End of Epoch 10/10 | Test Accuracy: 80.30% **
# --------------------------------------------
# ------------Combination: ['P', 'C']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/139], IRM Loss: 20.5332, SAE Loss: 32.1972
# Epoch [1/10], Step [80/139], IRM Loss: 20.4590, SAE Loss: 21.3427
# Epoch [1/10], Step [120/139], IRM Loss: 19.8276, SAE Loss: 6.0788
# ** End of Epoch 1/10 | Test Accuracy: 14.30% **
# Epoch [2/10], Step [40/139], IRM Loss: 15.7326, SAE Loss: 2.7391
# Epoch [2/10], Step [80/139], IRM Loss: 12.8553, SAE Loss: 3.0577
# Epoch [2/10], Step [120/139], IRM Loss: 8.6802, SAE Loss: 3.8806
# ** End of Epoch 2/10 | Test Accuracy: 32.10% **
# Epoch [3/10], Step [40/139], IRM Loss: 3.9540, SAE Loss: 4.0023
# Epoch [3/10], Step [80/139], IRM Loss: 2.6941, SAE Loss: 4.0473
# Epoch [3/10], Step [120/139], IRM Loss: 1.6519, SAE Loss: 4.2946
# ** End of Epoch 3/10 | Test Accuracy: 60.94% **
# Epoch [4/10], Step [40/139], IRM Loss: 1.7345, SAE Loss: 3.4067
# Epoch [4/10], Step [80/139], IRM Loss: 1.1899, SAE Loss: 3.6304
# Epoch [4/10], Step [120/139], IRM Loss: 1.6627, SAE Loss: 4.0272
# ** End of Epoch 4/10 | Test Accuracy: 66.85% **
# Epoch [5/10], Step [40/139], IRM Loss: 0.3445, SAE Loss: 4.0611
# Epoch [5/10], Step [80/139], IRM Loss: 0.3238, SAE Loss: 3.5934
# Epoch [5/10], Step [120/139], IRM Loss: 0.3376, SAE Loss: 3.4398
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-36f7812930d4> in <cell line: 1>()
#       4     lambda_sparse=[0.1, 0.1, 0.1]
#       5
# ----> 6     trained_model_sae_office = train_model_irm_sae_with_warmup_office(
#       7                 # model=trained_model_sae_office,
#       8                 batch_size=32,
#
# <ipython-input-12-c110e3e90d73> in train_model_irm_sae_with_warmup_office(batch_size, num_warmup_epochs, num_main_epochs, lr, lr_sae, lambda_irm, lambda_sae_rec, lambda_sae_sparse, device, loader, model, verbose, lambda_sparse, lambda_reconstruction, lambda_irm_pair)
#      46     print("===== Main Phase (IRM + SAE) =====")
#      47
# ---> 48     model = train_main_irm_multi_sae_office(model,
#      49                                             loader_source=loader_source,
#      50                                             test_loader=loader_target,
#
# <ipython-input-13-0b0cf470309d> in train_main_irm_multi_sae_office(model, loader_source, test_loader, num_epochs, lr, lr_sae, lambda_irm, lambda_sae_rec, lambda_sae_sparse, lambda_sparse, lambda_reconstruction, lambda_irm_pair, device, verbose)
#     108
#     109         # Evaluation after each epoch
# --> 110         test_acc = evaluate(model, test_loader, device=device)
#     111         print(f"** End of Epoch {epoch+1}/{num_epochs} | Test Accuracy: {test_acc:.2f}% **")
#     112
#
# <ipython-input-15-ca6ad6e21e26> in evaluate(model, loader, device)
#       6         for x, y in loader:
#       7             x, y = x.to(device), y.to(device)
# ----> 8             logits, _, _ = model(x)
#       9             preds = torch.argmax(logits, dim=1)
#      10             correct += (preds == y).sum().item()
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# <ipython-input-8-186842663404> in forward(self, x)
#      16         _, _, f4 = self.feature_extractor(x)
#      17
# ---> 18         x_recon4, z4 = self.sae4(f4)
#      19
#      20         class_logits = self.classifier(z4)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# <ipython-input-6-5a06b4a99292> in forward(self, x)
#      65
#      66     def forward(self, x):
# ---> 67         z = self.encoder(x)
#      68         x_recon = self.decoder(z)
#      69         return x_recon, z
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     248     def forward(self, input):
#     249         for module in self:
# --> 250             input = module(input)
#     251         return input
#     252
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/activation.py in forward(self, input)
#     131
#     132     def forward(self, input: Tensor) -> Tensor:
# --> 133         return F.relu(input, inplace=self.inplace)
#     134
#     135     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py in relu(input, inplace)
#    1700         return handle_torch_function(relu, (input,), input, inplace=inplace)
#    1701     if inplace:
# -> 1702         result = torch.relu_(input)
#    1703     else:
#    1704         result = torch.relu(input)
#
# KeyboardInterrupt:
