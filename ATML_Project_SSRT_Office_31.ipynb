# %%
# !git clone https://github.com/tsun/SSRT.git
# Out:
# Cloning into 'SSRT'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 67 (delta 19), reused 61 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (67/67), 3.73 MiB | 10.13 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
# !cp "/content/drive/MyDrive/ATML/Project/domain_adaptation_images.tar.gz" "SSRT"

# %%
# %cd SSRT
# Out:
# /content/SSRT

# %%
# !mkdir "data/office31"

# %%
# !tar -xf "domain_adaptation_images.tar.gz" -C "data/office31"

# %%
# !python3 main_ViT_baseline.office31.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Train iter:  54% 1083/2000 [08:34<07:31,  2.03it/s]
# Train iter:  54% 1084/2000 [08:34<07:21,  2.07it/s]
# Train iter:  54% 1085/2000 [08:35<07:15,  2.10it/s]
# Train iter:  54% 1086/2000 [08:35<07:11,  2.12it/s]
# Train iter:  54% 1087/2000 [08:36<07:05,  2.15it/s]
# Train iter:  54% 1088/2000 [08:36<07:02,  2.16it/s]
# Train iter:  54% 1089/2000 [08:37<07:01,  2.16it/s]
# Train iter:  55% 1090/2000 [08:37<06:59,  2.17it/s]
# Train iter:  55% 1091/2000 [08:38<06:58,  2.17it/s]
# Train iter:  55% 1092/2000 [08:38<06:57,  2.17it/s]
# Train iter:  55% 1093/2000 [08:39<06:57,  2.17it/s]
# Train iter:  55% 1094/2000 [08:39<06:56,  2.18it/s]
# Train iter:  55% 1095/2000 [08:39<06:55,  2.18it/s]
# Train iter:  55% 1096/2000 [08:40<07:57,  1.89it/s]
# Train iter:  55% 1097/2000 [08:41<07:36,  1.98it/s]
# Train iter:  55% 1098/2000 [08:41<07:22,  2.04it/s]
# Train iter:  55% 1099/2000 [08:42<07:13,  2.08it/s]
# ...

# %%
# !cp "/content/SSRT/checkpoint/vit_base_patch16_224/vitgrl_805.pth" "/content/drive/MyDrive/ATML/Project"

# %%
# !cp -r "/content/SSRT/checkpoint" "/content/drive/MyDrive/ATML/Project/vitgrl_backbones"

# %%
# !cp -r "/content/SSRT/logs" "/content/drive/MyDrive/ATML/Project/"
