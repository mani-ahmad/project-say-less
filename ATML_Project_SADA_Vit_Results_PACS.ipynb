# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 32.5 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.3 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.2 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.7 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.7 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
from torchvision import datasets, transforms, models
from torchvision.transforms import ToTensor
from torchvision.datasets import ImageFolder
from torchvision.models import vit_b_16

# Datasets
# from datasets import load_dataset
import kagglehub
from datasets import load_dataset

# Extra
import os
from copy import deepcopy
from PIL import Image
import matplotlib.pyplot as plt
import timm

# %% [markdown]
# ## Office-31

# %%
def Office31(domain, transform):
    path = kagglehub.dataset_download("xixuhu/office31")
    path = os.path.join(os.path.join(path, "Office-31"), domain)
    return datasets.ImageFolder(root=path, transform=transform)

def get_office_data_loaders(batch_size):

    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
    ])

    amazon_data = Office31("amazon", transform)
    dslr_data = Office31("dslr", transform)
    webcam_data = Office31("webcam", transform)

    loader_amazon = DataLoader(amazon_data, batch_size=batch_size, shuffle=True)
    loader_dslr = DataLoader(dslr_data, batch_size=batch_size, shuffle=True)
    loader_webcam = DataLoader(webcam_data, batch_size=batch_size, shuffle=True)

    return loader_amazon, loader_dslr, loader_webcam

# %% [markdown]
# ## Pacs

# %%
class PACSDataset(Dataset):
    def __init__(self, data, transform):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        example = self.data[idx]
        image = example['image']
        label = example['label']
        image = self.transform(image)
        return image, label

def get_pacs_data(domain_name, split="train"):
    """Loads a specific domain from the PACS dataset."""
    dataset = load_dataset("flwrlabs/pacs")[split]
    domain_data = dataset.filter(lambda example: example['domain'] == domain_name)

    return domain_data

def get_pacs_data_loaders(batch_size):
    """Creates data loaders for three domains in PACS."""
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    art_painting_data = get_pacs_data("art_painting", split="train")
    cartoon_data = get_pacs_data("cartoon", split="train")
    photo_data = get_pacs_data("photo", split="train")
    sketch_data = get_pacs_data("sketch", split="train")

    art_painting_dataset = PACSDataset(art_painting_data, transform)
    cartoon_dataset = PACSDataset(cartoon_data, transform)
    photo_dataset = PACSDataset(photo_data, transform)
    sketch_dataset = PACSDataset(sketch_data, transform)

    loader_art_painting = DataLoader(art_painting_dataset, batch_size=batch_size, shuffle=True)
    loader_cartoon = DataLoader(cartoon_dataset, batch_size=batch_size, shuffle=True)
    loader_photo = DataLoader(photo_dataset, batch_size=batch_size, shuffle=True)
    loader_sketch = DataLoader(sketch_dataset, batch_size=batch_size, shuffle=True)

    return loader_art_painting, loader_cartoon, loader_photo, loader_sketch

# %% [markdown]
# ## Model Cards

# %%
class ResNetFeatureExtractor(nn.Module):
    def __init__(self, pretrained=True):
        super().__init__()
        base_model = torchvision.models.resnet50(pretrained=pretrained)
        self.conv1 = base_model.conv1
        self.bn1 = base_model.bn1
        self.relu = base_model.relu
        self.maxpool = base_model.maxpool
        self.layer1 = base_model.layer1
        self.layer2 = base_model.layer2
        self.layer3 = base_model.layer3
        self.layer4 = base_model.layer4

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool(x)

        f_block1 = self.layer1(x)
        f_block2 = self.layer2(f_block1)
        f_block3 = self.layer3(f_block2)
        f_block4 = self.layer4(f_block3)

        return f_block2, f_block3, f_block4



class VitBasicFeatureExtractor(nn.Module):

    def __init__(self, pretrained=True, layers=[4, 8, 12]):
        super().__init__()

        self.model = timm.create_model('vit_base_patch16_224', pretrained=pretrained, features_only=True)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

    def forward(self, x):

        features = self.model(x)
        pooled_features = []
        for feature in features:
            pooled = self.avgpool(feature)
            pooled = pooled.view(pooled.size(0), -1)
            pooled_features.append(pooled)

        return tuple(pooled_features)

# %%
model = VitBasicFeatureExtractor(pretrained=True)

input = torch.randn(16, 3, 224, 224)
output = model(input)

for out in output:
    print(out.shape)
# Out:
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# torch.Size([16, 768])
# torch.Size([16, 768])
# torch.Size([16, 768])

# %%
import torch
import torch.nn as nn
import torch.nn.init as init

class SparseAutoencoder(nn.Module):

    def __init__(self, input_dim=2048, hidden_dim=1024, latent_dim=768, dropout_rate=0.3):
        super(SparseAutoencoder, self).__init__()

        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),

            nn.Linear(hidden_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),

            nn.Linear(hidden_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),

            nn.Linear(hidden_dim, latent_dim),
            nn.LayerNorm(latent_dim),
            nn.ReLU(inplace=True)
        )

        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),

            nn.Linear(hidden_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),

            nn.Linear(hidden_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),

            nn.Linear(hidden_dim, input_dim),
            nn.Sigmoid()
        )

        self._initialize_weights()

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                init.kaiming_uniform_(m.weight, a=0, nonlinearity='relu')
                if m.bias is not None:
                    init.zeros_(m.bias)
            elif isinstance(m, nn.LayerNorm):
                init.ones_(m.weight)
                init.zeros_(m.bias)

    def forward(self, x):
        z = self.encoder(x)
        x_recon = self.decoder(z)
        return x_recon, z

# %%
class UnifiedModelMultiBlockSAE(nn.Module):
    def __init__(self,
                 sae_dim_block2=128,
                 sae_dim_block3=256,
                 sae_dim_block4=256,
                 num_classes=7):
        super().__init__()

        self.feature_extractor = VitBasicFeatureExtractor(pretrained=True)

        self.sae2 = SparseAutoencoder(input_dim=768, latent_dim=768)
        self.sae3 = SparseAutoencoder(input_dim=768, latent_dim=768)
        self.sae4 = SparseAutoencoder(input_dim=768, latent_dim=768)


        self.classifier = nn.Sequential(
            nn.Linear(768, num_classes)
        )

    def forward(self, x):

        _, _, f4 = self.feature_extractor(x)
        x_recon4, z4 = self.sae4(f4)

        class_logits = self.classifier(z4)

        return (class_logits,
                (x_recon4, z4),
                (f4))

# %% [markdown]
# ## Losses

# %%
def irm_penalty(logits, labels):

    scale = torch.tensor(1.0, requires_grad=True, device=logits.device)
    loss_erm = F.cross_entropy(scale * logits, labels)

    grad = torch.autograd.grad(loss_erm, [scale], create_graph=True)[0]

    penalty = torch.sum(grad**2)
    var = 0.0

    return loss_erm, penalty, var

# %% [markdown]
# ## Trian and Evaluate Functions

# %% [markdown]
# ### Train

# %%
def train_model_irm_sae_with_warmup_office(
    batch_size=16,
    num_warmup_epochs=5,
    num_main_epochs=20,
    lr=1e-4,
    lr_sae=1e-4,
    lambda_irm=1.0,
    lambda_sae_rec=1.0,
    lambda_sae_sparse=1e-4,
    device='cuda',
    loader=['P', 'C'],
    model=None,
    verbose=False,
    lambda_sparse=[1.0, 1.0, 1.0],
    lambda_reconstruction=[1.0, 1.0, 1.0],
    lambda_irm_pair=[1.0, 1.0, 0.0],
):

    loader_art_painting, loader_cartoon, loader_photo, loader_sketch = get_pacs_data_loaders(batch_size)

    source, target = loader if loader is not None else ['P', 'C']

    if source == 'P':
        loader_source = loader_photo
    elif source == 'C':
        loader_source = loader_cartoon
    elif source == 'A':
        loader_source = loader_art_painting
    else:
        loader_source = loader_sketch

    if target == 'P':
        loader_target = loader_photo
    elif target == 'C':
        loader_target = loader_cartoon
    elif target == 'A':
        loader_target = loader_art_painting
    else:
        loader_target = loader_sketch


    if model is None:
        model = UnifiedModelMultiBlockSAE(512, 1024, 2048, 31)

    print("===== Main Phase (IRM + SAE) =====")

    model = train_main_irm_multi_sae_office(model,
                                            loader_source=loader_source,
                                            test_loader=loader_target,
                                            num_epochs=num_main_epochs,
                                            lr=lr,
                                            lr_sae=lr_sae,
                                            lambda_irm=lambda_irm,
                                            lambda_sae_rec=lambda_sae_rec,
                                            lambda_sae_sparse=lambda_sae_sparse,
                                            device=device,
                                            verbose=verbose,
                                            lambda_sparse=lambda_sparse,
                                            lambda_reconstruction=lambda_reconstruction,
                                            lambda_irm_pair=lambda_irm_pair
                                            )

    return model

# %% [markdown]
# ### Separate optm

# %%
def train_main_irm_multi_sae_office(
    model,
    loader_source,
    test_loader,
    num_epochs=20,
    lr=1e-4,
    lr_sae=1e-4,
    lambda_irm=1.0,
    lambda_sae_rec=1.0,
    lambda_sae_sparse=1e-4,
    lambda_sparse=[1.0, 1.0, 1.0],
    lambda_reconstruction=[1.0, 1.0, 1.0],
    lambda_irm_pair=[1.0, 1.0, 1.0],
    device='cuda',
    verbose=False
):
    import torch.optim as optim

    model.to(device)
    model.train()

    def sae_forward_splits(f4p):
        # x_recon2, z2 = model.sae2(f2p)
        # x_recon3, z3 = model.sae3(f3p)
        x_recon4, z4 = model.sae4(f4p)
        return x_recon4, z4

    # Define separate optimizers
    # Optimizer for the feature extractor and classifier
    params_rest = [
        p for n, p in model.named_parameters()
        if not (n.startswith('sae2') or n.startswith('sae3') or n.startswith('sae4'))
    ]
    # optimizer_rest = optim.SGD(params_rest, lr=lr, momentum=0.9)
    optimizer_rest = optim.Adam(params_rest, lr=lr)
    # Optimizer for the Sparse Autoencoders (sae2, sae3, sae4)
    params_sae = list(model.sae2.parameters()) + list(model.sae3.parameters()) + list(model.sae4.parameters())
    optimizer_sae = optim.Adam(params_sae, lr=lr_sae)

    for epoch in range(num_epochs):
        source_iter = iter(loader_source)
        steps_per_epoch = len(source_iter)

        for step in range(steps_per_epoch):

            try:
                x_s, y_s = next(source_iter)
            except StopIteration:
                source_iter = iter(loader_source)
                x_s, y_s = next(source_iter)

            x_s, y_s = x_s.to(device), y_s.to(device)

            # Forward pass for classification
            class_logits_s, _, _ = model(x_s)

            # Compute IRM loss
            loss_erm_s, penalty_s, var_s = irm_penalty(class_logits_s, y_s)

            irm_loss = 0.5 * loss_erm_s
            irm_pen  = 0.5 * penalty_s

            w1, w2, w3 = lambda_irm_pair
            loss_irm = w1 * irm_loss + w2 * (lambda_irm * irm_pen) + w3 * var_s

            # Forward pass for SAEs without tracking gradients
            with torch.no_grad():
                class_logits_s, (x_recon4_s, z4_s), (f4p_s) = model(x_s)

            # Forward pass through SAEs to get reconstructions and latent vectors
            x_recon4_s, z4_s = sae_forward_splits(f4p_s)

            # Compute Reconstruction Loss
            lambda_s1, lambda_s2, lambda_s3 = lambda_sparse
            lambda_r1, lambda_r2, lambda_r3 = lambda_reconstruction


            rec_loss4_s = F.mse_loss(x_recon4_s, f4p_s)
            rec_loss4   = lambda_r3 * rec_loss4_s

            rec_loss_total = rec_loss4

            l1_4_s = torch.mean(torch.abs(z4_s))
            l1_4   = lambda_s3 * l1_4_s

            l1_sparsity = l1_4

            # Total SAE Loss
            sae_loss = lambda_sae_rec * rec_loss_total + lambda_sae_sparse * l1_sparsity

            loss = loss_irm + sae_loss


            # Zero gradients for both optimizers
            optimizer_rest.zero_grad()
            optimizer_sae.zero_grad()

            # Backward pass
            loss.backward()

            # Update parameters
            optimizer_rest.step()
            optimizer_sae.step()

            if (step+1) % 40 == 0 and verbose:
                print(f"Epoch [{epoch+1}/{num_epochs}], Step [{step+1}/{steps_per_epoch}], "
                      f"IRM Loss: {loss_irm.item():.4f}, SAE Loss: {sae_loss.item():.4f}")

        # Evaluation after each epoch
        test_acc = evaluate(model, test_loader, device=device)
        print(f"** End of Epoch {epoch+1}/{num_epochs} | Test Accuracy: {test_acc:.2f}% **")

    return model

# %% [markdown]
# ### Evaluate

# %%
def evaluate_baseline(model, loader, device='cuda'):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            logits, _ = model(x)
            preds = torch.argmax(logits, dim=1)
            correct += (preds == y).sum().item()
            total += y.size(0)
    acc = 100.0 * correct / total
    model.train()
    return acc

# %%
def evaluate(model, loader, device='cuda'):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            logits, _, _ = model(x)
            preds = torch.argmax(logits, dim=1)
            correct += (preds == y).sum().item()
            total += y.size(0)
    acc = 100.0 * correct / total
    return acc

# %% [markdown]
# ### Ours

# %%
combinations = [["P", "C"], ["P", "A"], ["P", "S"], ["C", "A"], ["C", "S"], ["C", "P"], ["A", "P"], ["A", "C"], ["A", "S"], ["S", "P"], ["S", "C"], ["S", "A"]]

# %%
for comb in combinations:
  print(f"------------Combination: {comb}--------------")
  lambda_irm_pair = [10.0, 4.0, 0.0]
  lambda_sparse=[0.1, 0.1, 0.1]

  trained_model_sae_office = train_model_irm_sae_with_warmup_office(
              batch_size=32,
              num_warmup_epochs=4,
              num_main_epochs=10,
              lr=1e-5,
              lr_sae=5e-5,
              lambda_irm=1.0,
              lambda_sae_rec=2.0,
              lambda_sae_sparse=2e-4,
              device='cuda',
              verbose=True,
              lambda_irm_pair=lambda_irm_pair,
              lambda_sparse=lambda_sparse,
              loader=comb
          )

  print("--------------------------------------------")
# Out:
# ------------Combination: ['P', 'C']--------------
# README.md:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/191M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9991 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/9991 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/9991 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/9991 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/9991 [00:00<?, ? examples/s]
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/53], IRM Loss: 11.1331, SAE Loss: 6.9032
# ** End of Epoch 1/10 | Test Accuracy: 17.83% **
# Epoch [2/10], Step [40/53], IRM Loss: 1.7108, SAE Loss: 7.0705
# ** End of Epoch 2/10 | Test Accuracy: 34.73% **
# Epoch [3/10], Step [40/53], IRM Loss: 0.2453, SAE Loss: 6.8553
# ** End of Epoch 3/10 | Test Accuracy: 38.14% **
# Epoch [4/10], Step [40/53], IRM Loss: 0.1514, SAE Loss: 7.3088
# ** End of Epoch 4/10 | Test Accuracy: 40.19% **
# Epoch [5/10], Step [40/53], IRM Loss: 0.1275, SAE Loss: 7.2652
# ** End of Epoch 5/10 | Test Accuracy: 40.27% **
# Epoch [6/10], Step [40/53], IRM Loss: 0.0917, SAE Loss: 8.3012
# ** End of Epoch 6/10 | Test Accuracy: 39.93% **
# Epoch [7/10], Step [40/53], IRM Loss: 0.0893, SAE Loss: 7.8576
# ** End of Epoch 7/10 | Test Accuracy: 40.23% **
# Epoch [8/10], Step [40/53], IRM Loss: 0.0529, SAE Loss: 6.6462
# ** End of Epoch 8/10 | Test Accuracy: 40.74% **
# Epoch [9/10], Step [40/53], IRM Loss: 0.0576, SAE Loss: 8.4372
# ** End of Epoch 9/10 | Test Accuracy: 40.91% **
# Epoch [10/10], Step [40/53], IRM Loss: 0.0489, SAE Loss: 8.2382
# ** End of Epoch 10/10 | Test Accuracy: 41.08% **
# --------------------------------------------
# ------------Combination: ['P', 'A']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/53], IRM Loss: 10.6307, SAE Loss: 5.8743
# ** End of Epoch 1/10 | Test Accuracy: 26.07% **
# Epoch [2/10], Step [40/53], IRM Loss: 3.1357, SAE Loss: 5.4430
# ** End of Epoch 2/10 | Test Accuracy: 63.04% **
# Epoch [3/10], Step [40/53], IRM Loss: 0.3719, SAE Loss: 6.1726
# ** End of Epoch 3/10 | Test Accuracy: 69.19% **
# Epoch [4/10], Step [40/53], IRM Loss: 0.1649, SAE Loss: 6.8889
# ** End of Epoch 4/10 | Test Accuracy: 69.78% **
# Epoch [5/10], Step [40/53], IRM Loss: 0.1732, SAE Loss: 6.3115
# ** End of Epoch 5/10 | Test Accuracy: 69.87% **
# Epoch [6/10], Step [40/53], IRM Loss: 0.1210, SAE Loss: 7.9275
# ** End of Epoch 6/10 | Test Accuracy: 69.78% **
# Epoch [7/10], Step [40/53], IRM Loss: 0.0846, SAE Loss: 6.2156
# ** End of Epoch 7/10 | Test Accuracy: 69.92% **
# Epoch [8/10], Step [40/53], IRM Loss: 0.0689, SAE Loss: 6.8534
# ** End of Epoch 8/10 | Test Accuracy: 70.17% **
# Epoch [9/10], Step [40/53], IRM Loss: 0.0847, SAE Loss: 6.9897
# ** End of Epoch 9/10 | Test Accuracy: 70.12% **
# Epoch [10/10], Step [40/53], IRM Loss: 0.0537, SAE Loss: 7.1734
# ** End of Epoch 10/10 | Test Accuracy: 70.21% **
# --------------------------------------------
# ------------Combination: ['P', 'S']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/53], IRM Loss: 11.0076, SAE Loss: 6.6590
# ** End of Epoch 1/10 | Test Accuracy: 4.07% **
# Epoch [2/10], Step [40/53], IRM Loss: 2.9191, SAE Loss: 6.2517
# ** End of Epoch 2/10 | Test Accuracy: 15.75% **
# Epoch [3/10], Step [40/53], IRM Loss: 0.5961, SAE Loss: 6.7559
# ** End of Epoch 3/10 | Test Accuracy: 17.66% **
# Epoch [4/10], Step [40/53], IRM Loss: 0.1622, SAE Loss: 6.7420
# ** End of Epoch 4/10 | Test Accuracy: 18.66% **
# Epoch [5/10], Step [40/53], IRM Loss: 0.1169, SAE Loss: 7.4679
# ** End of Epoch 5/10 | Test Accuracy: 19.45% **
# Epoch [6/10], Step [40/53], IRM Loss: 0.0944, SAE Loss: 7.4624
# ** End of Epoch 6/10 | Test Accuracy: 20.01% **
# Epoch [7/10], Step [40/53], IRM Loss: 0.0781, SAE Loss: 7.7389
# ** End of Epoch 7/10 | Test Accuracy: 20.21% **
# Epoch [8/10], Step [40/53], IRM Loss: 0.0745, SAE Loss: 6.6095
# ** End of Epoch 8/10 | Test Accuracy: 20.57% **
# Epoch [9/10], Step [40/53], IRM Loss: 0.0653, SAE Loss: 7.7670
# ** End of Epoch 9/10 | Test Accuracy: 20.74% **
# Epoch [10/10], Step [40/53], IRM Loss: 0.0547, SAE Loss: 7.4996
# ** End of Epoch 10/10 | Test Accuracy: 20.62% **
# --------------------------------------------
# ------------Combination: ['C', 'A']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/74], IRM Loss: 11.9812, SAE Loss: 5.8492
# ** End of Epoch 1/10 | Test Accuracy: 12.50% **
# Epoch [2/10], Step [40/74], IRM Loss: 6.5820, SAE Loss: 3.3245
# ** End of Epoch 2/10 | Test Accuracy: 59.03% **
# Epoch [3/10], Step [40/74], IRM Loss: 1.9506, SAE Loss: 3.5497
# ** End of Epoch 3/10 | Test Accuracy: 77.64% **
# Epoch [4/10], Step [40/74], IRM Loss: 0.4250, SAE Loss: 3.4480
# ** End of Epoch 4/10 | Test Accuracy: 81.01% **
# Epoch [5/10], Step [40/74], IRM Loss: 0.2022, SAE Loss: 3.8968
# ** End of Epoch 5/10 | Test Accuracy: 83.69% **
# Epoch [6/10], Step [40/74], IRM Loss: 0.1164, SAE Loss: 4.0044
# ** End of Epoch 6/10 | Test Accuracy: 85.11% **
# Epoch [7/10], Step [40/74], IRM Loss: 0.1545, SAE Loss: 3.3875
# ** End of Epoch 7/10 | Test Accuracy: 85.64% **
# Epoch [8/10], Step [40/74], IRM Loss: 0.0901, SAE Loss: 4.4823
# ** End of Epoch 8/10 | Test Accuracy: 86.08% **
# Epoch [9/10], Step [40/74], IRM Loss: 0.0655, SAE Loss: 3.5925
# ** End of Epoch 9/10 | Test Accuracy: 86.43% **
# Epoch [10/10], Step [40/74], IRM Loss: 0.0712, SAE Loss: 3.7504
# ** End of Epoch 10/10 | Test Accuracy: 86.47% **
# --------------------------------------------
# ------------Combination: ['C', 'S']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/74], IRM Loss: 11.7130, SAE Loss: 5.4806
# ** End of Epoch 1/10 | Test Accuracy: 17.00% **
# Epoch [2/10], Step [40/74], IRM Loss: 5.9464, SAE Loss: 3.3358
# ** End of Epoch 2/10 | Test Accuracy: 21.40% **
# Epoch [3/10], Step [40/74], IRM Loss: 2.0837, SAE Loss: 3.5683
# ** End of Epoch 3/10 | Test Accuracy: 29.22% **
# Epoch [4/10], Step [40/74], IRM Loss: 0.9146, SAE Loss: 3.3217
# ** End of Epoch 4/10 | Test Accuracy: 30.87% **
# Epoch [5/10], Step [40/74], IRM Loss: 0.4570, SAE Loss: 3.5785
# ** End of Epoch 5/10 | Test Accuracy: 31.81% **
# Epoch [6/10], Step [40/74], IRM Loss: 0.2216, SAE Loss: 3.4486
# ** End of Epoch 6/10 | Test Accuracy: 33.29% **
# Epoch [7/10], Step [40/74], IRM Loss: 0.1195, SAE Loss: 3.4439
# ** End of Epoch 7/10 | Test Accuracy: 35.33% **
# Epoch [8/10], Step [40/74], IRM Loss: 0.0966, SAE Loss: 3.7024
# ** End of Epoch 8/10 | Test Accuracy: 34.44% **
# Epoch [9/10], Step [40/74], IRM Loss: 0.0700, SAE Loss: 3.3259
# ** End of Epoch 9/10 | Test Accuracy: 35.45% **
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-a8b2ae04d8f4> in <cell line: 1>()
#       4   lambda_sparse=[0.1, 0.1, 0.1]
#       5
# ----> 6   trained_model_sae_office = train_model_irm_sae_with_warmup_office(
#       7               batch_size=32,
#       8               num_warmup_epochs=4,
#
# <ipython-input-9-0d79f2a0a35b> in train_model_irm_sae_with_warmup_office(batch_size, num_warmup_epochs, num_main_epochs, lr, lr_sae, lambda_irm, lambda_sae_rec, lambda_sae_sparse, device, loader, model, verbose, lambda_sparse, lambda_reconstruction, lambda_irm_pair)
#      45     print("===== Main Phase (IRM + SAE) =====")
#      46
# ---> 47     model = train_main_irm_multi_sae_office(model,
#      48                                             loader_source=loader_source,
#      49                                             test_loader=loader_target,
#
# <ipython-input-10-5da861576543> in train_main_irm_multi_sae_office(model, loader_source, test_loader, num_epochs, lr, lr_sae, lambda_irm, lambda_sae_rec, lambda_sae_sparse, lambda_sparse, lambda_reconstruction, lambda_irm_pair, device, verbose)
#      50                 x_s, y_s = next(source_iter)
#      51
# ---> 52             x_s, y_s = x_s.to(device), y_s.to(device)
#      53
#      54             # Forward pass for classification
#
# KeyboardInterrupt:

# %%
combinations = [ ["P", "S"], ["C", "S"], ["S", "P"], ["S", "C"]]

# %%
for comb in combinations:
  print(f"------------Combination: {comb}--------------")
  lambda_irm_pair = [10.0, 4.0, 0.0]
  lambda_sparse=[0.1, 0.1, 0.1]

  trained_model_sae_office = train_model_irm_sae_with_warmup_office(
              batch_size=32,
              num_warmup_epochs=4,
              num_main_epochs=10,
              lr=1e-5,
              lr_sae=5e-5,
              lambda_irm=1.0,
              lambda_sae_rec=2.0,
              lambda_sae_sparse=2e-4,
              device='cuda',
              verbose=True,
              lambda_irm_pair=lambda_irm_pair,
              lambda_sparse=lambda_sparse,
              loader=comb
          )

  print("--------------------------------------------")
# Out:
# ------------Combination: ['P', 'A']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/53], IRM Loss: 10.0728, SAE Loss: 7.5633
# ** End of Epoch 1/10 | Test Accuracy: 32.28% **
# Epoch [2/10], Step [40/53], IRM Loss: 1.0709, SAE Loss: 15.4023
# ** End of Epoch 2/10 | Test Accuracy: 70.17% **
# Epoch [3/10], Step [40/53], IRM Loss: 0.1366, SAE Loss: 12.6714
# ** End of Epoch 3/10 | Test Accuracy: 73.39% **
# Epoch [4/10], Step [40/53], IRM Loss: 0.0872, SAE Loss: 17.4451
# ** End of Epoch 4/10 | Test Accuracy: 71.83% **
# Epoch [5/10], Step [40/53], IRM Loss: 0.0649, SAE Loss: 17.2384
# ** End of Epoch 5/10 | Test Accuracy: 71.44% **
# Epoch [6/10], Step [40/53], IRM Loss: 0.0544, SAE Loss: 15.4382
# ** End of Epoch 6/10 | Test Accuracy: 71.14% **
# Epoch [7/10], Step [40/53], IRM Loss: 0.0439, SAE Loss: 17.4512
# ** End of Epoch 7/10 | Test Accuracy: 71.39% **
# Epoch [8/10], Step [40/53], IRM Loss: 0.0370, SAE Loss: 13.7259
# ** End of Epoch 8/10 | Test Accuracy: 70.95% **
# Epoch [9/10], Step [40/53], IRM Loss: 0.0339, SAE Loss: 15.4152
# ** End of Epoch 9/10 | Test Accuracy: 70.75% **
# Epoch [10/10], Step [40/53], IRM Loss: 0.0306, SAE Loss: 18.6816
# ** End of Epoch 10/10 | Test Accuracy: 70.61% **
# --------------------------------------------
# ------------Combination: ['C', 'A']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/74], IRM Loss: 10.9728, SAE Loss: 3.9616
# ** End of Epoch 1/10 | Test Accuracy: 50.93% **
# Epoch [2/10], Step [40/74], IRM Loss: 1.1708, SAE Loss: 4.2803
# ** End of Epoch 2/10 | Test Accuracy: 79.15% **
# Epoch [3/10], Step [40/74], IRM Loss: 0.3246, SAE Loss: 5.3685
# ** End of Epoch 3/10 | Test Accuracy: 82.13% **
# Epoch [4/10], Step [40/74], IRM Loss: 0.1017, SAE Loss: 5.1255
# ** End of Epoch 4/10 | Test Accuracy: 78.96% **
# Epoch [5/10], Step [40/74], IRM Loss: 0.0713, SAE Loss: 5.1196
# ** End of Epoch 5/10 | Test Accuracy: 78.76% **
# Epoch [6/10], Step [40/74], IRM Loss: 0.0450, SAE Loss: 4.0356
# ** End of Epoch 6/10 | Test Accuracy: 82.42% **
# Epoch [7/10], Step [40/74], IRM Loss: 0.0379, SAE Loss: 5.4881
# ** End of Epoch 7/10 | Test Accuracy: 82.42% **
# Epoch [8/10], Step [40/74], IRM Loss: 0.0322, SAE Loss: 5.6105
# ** End of Epoch 8/10 | Test Accuracy: 82.42% **
# Epoch [9/10], Step [40/74], IRM Loss: 0.0287, SAE Loss: 5.9878
# ** End of Epoch 9/10 | Test Accuracy: 82.32% **
# Epoch [10/10], Step [40/74], IRM Loss: 0.0260, SAE Loss: 5.2562
# ** End of Epoch 10/10 | Test Accuracy: 82.42% **
# --------------------------------------------
# ------------Combination: ['C', 'S']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/74], IRM Loss: 11.3577, SAE Loss: 8.4291
# ** End of Epoch 1/10 | Test Accuracy: 18.83% **
# Epoch [2/10], Step [40/74], IRM Loss: 2.5751, SAE Loss: 10.4128
# ** End of Epoch 2/10 | Test Accuracy: 34.69% **
# Epoch [3/10], Step [40/74], IRM Loss: 0.2317, SAE Loss: 8.8899
# ** End of Epoch 3/10 | Test Accuracy: 47.80% **
# Epoch [4/10], Step [40/74], IRM Loss: 0.0858, SAE Loss: 11.7765
# ** End of Epoch 4/10 | Test Accuracy: 41.51% **
# Epoch [5/10], Step [40/74], IRM Loss: 0.0631, SAE Loss: 10.0146
# ** End of Epoch 5/10 | Test Accuracy: 40.42% **
# Epoch [6/10], Step [40/74], IRM Loss: 0.0478, SAE Loss: 11.0844
# ** End of Epoch 6/10 | Test Accuracy: 45.64% **
# Epoch [7/10], Step [40/74], IRM Loss: 0.0323, SAE Loss: 9.8535
# ** End of Epoch 7/10 | Test Accuracy: 45.25% **
# Epoch [8/10], Step [40/74], IRM Loss: 0.0307, SAE Loss: 8.4943
# ** End of Epoch 8/10 | Test Accuracy: 45.33% **
# Epoch [9/10], Step [40/74], IRM Loss: 0.0280, SAE Loss: 9.9477
# ** End of Epoch 9/10 | Test Accuracy: 45.15% **
# Epoch [10/10], Step [40/74], IRM Loss: 0.0230, SAE Loss: 10.0999
# ** End of Epoch 10/10 | Test Accuracy: 45.28% **
# --------------------------------------------
# ------------Combination: ['C', 'P']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/74], IRM Loss: 12.1864, SAE Loss: 3.9733
# ** End of Epoch 1/10 | Test Accuracy: 33.59% **
# Epoch [2/10], Step [40/74], IRM Loss: 3.8876, SAE Loss: 5.0277
# ** End of Epoch 2/10 | Test Accuracy: 84.31% **
# Epoch [3/10], Step [40/74], IRM Loss: 0.1849, SAE Loss: 5.1660
# ** End of Epoch 3/10 | Test Accuracy: 93.41% **
# Epoch [4/10], Step [40/74], IRM Loss: 0.1436, SAE Loss: 4.4087
# ** End of Epoch 4/10 | Test Accuracy: 93.53% **
# Epoch [5/10], Step [40/74], IRM Loss: 0.0641, SAE Loss: 4.5779
# ** End of Epoch 5/10 | Test Accuracy: 95.39% **
# Epoch [6/10], Step [40/74], IRM Loss: 0.0485, SAE Loss: 4.4533
# ** End of Epoch 6/10 | Test Accuracy: 96.65% **
# Epoch [7/10], Step [40/74], IRM Loss: 0.0377, SAE Loss: 4.6094
# ** End of Epoch 7/10 | Test Accuracy: 96.53% **
# Epoch [8/10], Step [40/74], IRM Loss: 0.0363, SAE Loss: 4.6052
# ** End of Epoch 8/10 | Test Accuracy: 96.71% **
# Epoch [9/10], Step [40/74], IRM Loss: 0.0306, SAE Loss: 4.5472
# ** End of Epoch 9/10 | Test Accuracy: 96.71% **
# Epoch [10/10], Step [40/74], IRM Loss: 0.0249, SAE Loss: 4.6055
# ** End of Epoch 10/10 | Test Accuracy: 96.71% **
# --------------------------------------------
# ------------Combination: ['A', 'P']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/64], IRM Loss: 10.9742, SAE Loss: 5.0650
# ** End of Epoch 1/10 | Test Accuracy: 36.53% **
# Epoch [2/10], Step [40/64], IRM Loss: 1.9233, SAE Loss: 12.4522
# ** End of Epoch 2/10 | Test Accuracy: 99.16% **
# Epoch [3/10], Step [40/64], IRM Loss: 0.1633, SAE Loss: 15.2225
# ** End of Epoch 3/10 | Test Accuracy: 99.58% **
# Epoch [4/10], Step [40/64], IRM Loss: 0.1104, SAE Loss: 14.7619
# ** End of Epoch 4/10 | Test Accuracy: 99.34% **
# Epoch [5/10], Step [40/64], IRM Loss: 0.0761, SAE Loss: 13.4544
# ** End of Epoch 5/10 | Test Accuracy: 99.46% **
# Epoch [6/10], Step [40/64], IRM Loss: 0.0524, SAE Loss: 13.0903
# ** End of Epoch 6/10 | Test Accuracy: 99.46% **
# Epoch [7/10], Step [40/64], IRM Loss: 0.0435, SAE Loss: 11.8207
# ** End of Epoch 7/10 | Test Accuracy: 99.40% **
# Epoch [8/10], Step [40/64], IRM Loss: 0.0405, SAE Loss: 14.0474
# ** End of Epoch 8/10 | Test Accuracy: 99.40% **
# Epoch [9/10], Step [40/64], IRM Loss: 0.0322, SAE Loss: 13.6740
# ** End of Epoch 9/10 | Test Accuracy: 99.40% **
# Epoch [10/10], Step [40/64], IRM Loss: 0.0291, SAE Loss: 12.0200
# ** End of Epoch 10/10 | Test Accuracy: 99.40% **
# --------------------------------------------
# ------------Combination: ['A', 'C']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/64], IRM Loss: 11.0534, SAE Loss: 5.3218
# ** End of Epoch 1/10 | Test Accuracy: 17.75% **
# Epoch [2/10], Step [40/64], IRM Loss: 3.5712, SAE Loss: 8.4344
# ** End of Epoch 2/10 | Test Accuracy: 65.87% **
# Epoch [3/10], Step [40/64], IRM Loss: 1.4125, SAE Loss: 10.6434
# ** End of Epoch 3/10 | Test Accuracy: 74.70% **
# Epoch [4/10], Step [40/64], IRM Loss: 0.1091, SAE Loss: 7.2589
# ** End of Epoch 4/10 | Test Accuracy: 71.12% **
# Epoch [5/10], Step [40/64], IRM Loss: 0.0672, SAE Loss: 10.6525
# ** End of Epoch 5/10 | Test Accuracy: 73.81% **
# Epoch [6/10], Step [40/64], IRM Loss: 0.0533, SAE Loss: 10.3102
# ** End of Epoch 6/10 | Test Accuracy: 73.72% **
# Epoch [7/10], Step [40/64], IRM Loss: 0.0440, SAE Loss: 9.9351
# ** End of Epoch 7/10 | Test Accuracy: 73.72% **
# Epoch [8/10], Step [40/64], IRM Loss: 0.0387, SAE Loss: 11.4981
# ** End of Epoch 8/10 | Test Accuracy: 73.46% **
# Epoch [9/10], Step [40/64], IRM Loss: 0.0354, SAE Loss: 11.4289
# ** End of Epoch 9/10 | Test Accuracy: 73.46% **
# Epoch [10/10], Step [40/64], IRM Loss: 0.0315, SAE Loss: 11.4506
# ** End of Epoch 10/10 | Test Accuracy: 73.46% **
# --------------------------------------------
# ------------Combination: ['A', 'S']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/64], IRM Loss: 11.6007, SAE Loss: 5.0960
# ** End of Epoch 1/10 | Test Accuracy: 4.07% **
# Epoch [2/10], Step [40/64], IRM Loss: 1.7426, SAE Loss: 9.0837
# ** End of Epoch 2/10 | Test Accuracy: 54.90% **
# Epoch [3/10], Step [40/64], IRM Loss: 0.2146, SAE Loss: 12.2173
# ** End of Epoch 3/10 | Test Accuracy: 57.67% **
# Epoch [4/10], Step [40/64], IRM Loss: 0.2124, SAE Loss: 12.1558
# ** End of Epoch 4/10 | Test Accuracy: 56.76% **
# Epoch [5/10], Step [40/64], IRM Loss: 0.0803, SAE Loss: 12.2317
# ** End of Epoch 5/10 | Test Accuracy: 58.13% **
# Epoch [6/10], Step [40/64], IRM Loss: 0.0530, SAE Loss: 11.8569
# ** End of Epoch 6/10 | Test Accuracy: 58.64% **
# Epoch [7/10], Step [40/64], IRM Loss: 0.0468, SAE Loss: 13.9602
# ** End of Epoch 7/10 | Test Accuracy: 58.77% **
# Epoch [8/10], Step [40/64], IRM Loss: 0.0377, SAE Loss: 14.4290
# ** End of Epoch 8/10 | Test Accuracy: 58.87% **
# Epoch [9/10], Step [40/64], IRM Loss: 0.0372, SAE Loss: 15.1429
# ** End of Epoch 9/10 | Test Accuracy: 58.97% **
# Epoch [10/10], Step [40/64], IRM Loss: 0.0333, SAE Loss: 14.7383
# ** End of Epoch 10/10 | Test Accuracy: 59.12% **
# --------------------------------------------
# ------------Combination: ['S', 'P']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/123], IRM Loss: 10.4178, SAE Loss: 7.9697
# Epoch [1/10], Step [80/123], IRM Loss: 7.9330, SAE Loss: 6.7267
# Epoch [1/10], Step [120/123], IRM Loss: 6.8551, SAE Loss: 6.6614
# ** End of Epoch 1/10 | Test Accuracy: 12.75% **
# Epoch [2/10], Step [40/123], IRM Loss: 4.1377, SAE Loss: 6.7148
# Epoch [2/10], Step [80/123], IRM Loss: 3.9459, SAE Loss: 5.0582
# Epoch [2/10], Step [120/123], IRM Loss: 2.6332, SAE Loss: 5.6060
# ** End of Epoch 2/10 | Test Accuracy: 20.90% **
# Epoch [3/10], Step [40/123], IRM Loss: 1.9747, SAE Loss: 5.4231
# Epoch [3/10], Step [80/123], IRM Loss: 1.1921, SAE Loss: 5.9378
# Epoch [3/10], Step [120/123], IRM Loss: 2.8726, SAE Loss: 5.2509
# ** End of Epoch 3/10 | Test Accuracy: 33.77% **
# Epoch [4/10], Step [40/123], IRM Loss: 0.7763, SAE Loss: 5.0955
# Epoch [4/10], Step [80/123], IRM Loss: 0.3284, SAE Loss: 5.0953
# Epoch [4/10], Step [120/123], IRM Loss: 0.6872, SAE Loss: 5.0909
# ** End of Epoch 4/10 | Test Accuracy: 37.54% **
# Epoch [5/10], Step [40/123], IRM Loss: 0.4904, SAE Loss: 4.8940
# Epoch [5/10], Step [80/123], IRM Loss: 0.1143, SAE Loss: 5.6577
# Epoch [5/10], Step [120/123], IRM Loss: 0.1802, SAE Loss: 5.5214
# ** End of Epoch 5/10 | Test Accuracy: 42.34% **
# Epoch [6/10], Step [40/123], IRM Loss: 0.0541, SAE Loss: 6.0956
# Epoch [6/10], Step [80/123], IRM Loss: 0.0730, SAE Loss: 6.0104
# Epoch [6/10], Step [120/123], IRM Loss: 0.0431, SAE Loss: 5.5744
# ** End of Epoch 6/10 | Test Accuracy: 43.77% **
# Epoch [7/10], Step [40/123], IRM Loss: 0.0394, SAE Loss: 5.6297
# Epoch [7/10], Step [80/123], IRM Loss: 0.0488, SAE Loss: 5.7845
# Epoch [7/10], Step [120/123], IRM Loss: 0.0369, SAE Loss: 6.4786
# ** End of Epoch 7/10 | Test Accuracy: 42.99% **
# Epoch [8/10], Step [40/123], IRM Loss: 0.0371, SAE Loss: 6.2095
# Epoch [8/10], Step [80/123], IRM Loss: 0.0253, SAE Loss: 5.9509
# Epoch [8/10], Step [120/123], IRM Loss: 0.0273, SAE Loss: 6.0263
# ** End of Epoch 8/10 | Test Accuracy: 44.01% **
# Epoch [9/10], Step [40/123], IRM Loss: 0.0332, SAE Loss: 6.3295
# Epoch [9/10], Step [80/123], IRM Loss: 0.0231, SAE Loss: 6.2699
# Epoch [9/10], Step [120/123], IRM Loss: 0.0225, SAE Loss: 5.7843
# ** End of Epoch 9/10 | Test Accuracy: 44.73% **
# Epoch [10/10], Step [40/123], IRM Loss: 0.0194, SAE Loss: 5.7916
# Epoch [10/10], Step [80/123], IRM Loss: 0.0212, SAE Loss: 6.8242
# Epoch [10/10], Step [120/123], IRM Loss: 0.0180, SAE Loss: 6.2387
# ** End of Epoch 10/10 | Test Accuracy: 45.21% **
# --------------------------------------------
# ------------Combination: ['S', 'C']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/123], IRM Loss: 11.3363, SAE Loss: 5.7057
# Epoch [1/10], Step [80/123], IRM Loss: 8.6171, SAE Loss: 5.4835
# Epoch [1/10], Step [120/123], IRM Loss: 6.3326, SAE Loss: 4.9117
# ** End of Epoch 1/10 | Test Accuracy: 22.01% **
# Epoch [2/10], Step [40/123], IRM Loss: 3.7045, SAE Loss: 3.8663
# Epoch [2/10], Step [80/123], IRM Loss: 3.5277, SAE Loss: 3.5880
# Epoch [2/10], Step [120/123], IRM Loss: 2.0299, SAE Loss: 3.1245
# ** End of Epoch 2/10 | Test Accuracy: 36.31% **
# Epoch [3/10], Step [40/123], IRM Loss: 1.4554, SAE Loss: 3.0860
# Epoch [3/10], Step [80/123], IRM Loss: 1.6916, SAE Loss: 2.7609
# Epoch [3/10], Step [120/123], IRM Loss: 1.0122, SAE Loss: 3.0923
# ** End of Epoch 3/10 | Test Accuracy: 42.32% **
# Epoch [4/10], Step [40/123], IRM Loss: 0.2333, SAE Loss: 3.0802
# Epoch [4/10], Step [80/123], IRM Loss: 1.9065, SAE Loss: 3.0046
# Epoch [4/10], Step [120/123], IRM Loss: 0.1793, SAE Loss: 3.1014
# ** End of Epoch 4/10 | Test Accuracy: 49.87% **
# Epoch [5/10], Step [40/123], IRM Loss: 1.1137, SAE Loss: 3.8882
# Epoch [5/10], Step [80/123], IRM Loss: 0.1493, SAE Loss: 2.6742
# Epoch [5/10], Step [120/123], IRM Loss: 0.1932, SAE Loss: 3.1399
# ** End of Epoch 5/10 | Test Accuracy: 52.47% **
# Epoch [6/10], Step [40/123], IRM Loss: 0.0614, SAE Loss: 2.7517
# Epoch [6/10], Step [80/123], IRM Loss: 0.0607, SAE Loss: 3.2077
# Epoch [6/10], Step [120/123], IRM Loss: 0.0370, SAE Loss: 3.0041
# ** End of Epoch 6/10 | Test Accuracy: 48.51% **
# Epoch [7/10], Step [40/123], IRM Loss: 0.2121, SAE Loss: 3.0319
# Epoch [7/10], Step [80/123], IRM Loss: 0.0277, SAE Loss: 3.5631
# Epoch [7/10], Step [120/123], IRM Loss: 0.0301, SAE Loss: 3.0883
# ** End of Epoch 7/10 | Test Accuracy: 51.62% **
# Epoch [8/10], Step [40/123], IRM Loss: 0.0331, SAE Loss: 3.1612
# Epoch [8/10], Step [80/123], IRM Loss: 0.0239, SAE Loss: 3.3832
# Epoch [8/10], Step [120/123], IRM Loss: 0.0214, SAE Loss: 3.1205
# ** End of Epoch 8/10 | Test Accuracy: 53.03% **
# Epoch [9/10], Step [40/123], IRM Loss: 0.0223, SAE Loss: 3.1596
# Epoch [9/10], Step [80/123], IRM Loss: 0.0203, SAE Loss: 3.3401
# Epoch [9/10], Step [120/123], IRM Loss: 0.0206, SAE Loss: 3.3937
# ** End of Epoch 9/10 | Test Accuracy: 53.63% **
# Epoch [10/10], Step [40/123], IRM Loss: 0.0164, SAE Loss: 3.3595
# Epoch [10/10], Step [80/123], IRM Loss: 0.0229, SAE Loss: 3.5812
# Epoch [10/10], Step [120/123], IRM Loss: 0.0211, SAE Loss: 3.2319
# ** End of Epoch 10/10 | Test Accuracy: 53.20% **
# --------------------------------------------
# ------------Combination: ['S', 'A']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/123], IRM Loss: 11.8063, SAE Loss: 7.1906
# Epoch [1/10], Step [80/123], IRM Loss: 8.1803, SAE Loss: 5.6593
# Epoch [1/10], Step [120/123], IRM Loss: 5.6677, SAE Loss: 5.8846
# ** End of Epoch 1/10 | Test Accuracy: 23.14% **
# Epoch [2/10], Step [40/123], IRM Loss: 1.4349, SAE Loss: 5.7324
# Epoch [2/10], Step [80/123], IRM Loss: 2.5686, SAE Loss: 4.2136
# Epoch [2/10], Step [120/123], IRM Loss: 1.6654, SAE Loss: 4.1014
# ** End of Epoch 2/10 | Test Accuracy: 55.47% **
# Epoch [3/10], Step [40/123], IRM Loss: 0.4373, SAE Loss: 4.5818
# Epoch [3/10], Step [80/123], IRM Loss: 0.2152, SAE Loss: 5.1415
# Epoch [3/10], Step [120/123], IRM Loss: 1.0301, SAE Loss: 4.0559
# ** End of Epoch 3/10 | Test Accuracy: 58.35% **
# Epoch [4/10], Step [40/123], IRM Loss: 0.0910, SAE Loss: 4.5656
# Epoch [4/10], Step [80/123], IRM Loss: 0.7397, SAE Loss: 3.7978
# Epoch [4/10], Step [120/123], IRM Loss: 0.0964, SAE Loss: 4.8303
# ** End of Epoch 4/10 | Test Accuracy: 61.67% **
# Epoch [5/10], Step [40/123], IRM Loss: 0.0608, SAE Loss: 4.7863
# Epoch [5/10], Step [80/123], IRM Loss: 0.0568, SAE Loss: 4.7858
# Epoch [5/10], Step [120/123], IRM Loss: 0.1083, SAE Loss: 6.5968
# ** End of Epoch 5/10 | Test Accuracy: 60.11% **
# Epoch [6/10], Step [40/123], IRM Loss: 0.0393, SAE Loss: 5.6814
# Epoch [6/10], Step [80/123], IRM Loss: 0.0342, SAE Loss: 4.9779
# Epoch [6/10], Step [120/123], IRM Loss: 0.0355, SAE Loss: 6.7851
# ** End of Epoch 6/10 | Test Accuracy: 62.35% **
# Epoch [7/10], Step [40/123], IRM Loss: 0.0437, SAE Loss: 4.7764
# Epoch [7/10], Step [80/123], IRM Loss: 0.0381, SAE Loss: 4.5046
# Epoch [7/10], Step [120/123], IRM Loss: 0.0431, SAE Loss: 5.5514
# ** End of Epoch 7/10 | Test Accuracy: 67.09% **
# Epoch [8/10], Step [40/123], IRM Loss: 0.0359, SAE Loss: 5.9348
# Epoch [8/10], Step [80/123], IRM Loss: 0.0295, SAE Loss: 6.4439
# Epoch [8/10], Step [120/123], IRM Loss: 0.0258, SAE Loss: 5.8627
# ** End of Epoch 8/10 | Test Accuracy: 69.34% **
# Epoch [9/10], Step [40/123], IRM Loss: 0.0218, SAE Loss: 6.0815
# Epoch [9/10], Step [80/123], IRM Loss: 0.0193, SAE Loss: 6.9520
# Epoch [9/10], Step [120/123], IRM Loss: 0.0214, SAE Loss: 5.2468
# ** End of Epoch 9/10 | Test Accuracy: 70.80% **
# Epoch [10/10], Step [40/123], IRM Loss: 0.0799, SAE Loss: 4.9047
# Epoch [10/10], Step [80/123], IRM Loss: 0.0460, SAE Loss: 5.3862
# Epoch [10/10], Step [120/123], IRM Loss: 0.1170, SAE Loss: 4.6351
# ** End of Epoch 10/10 | Test Accuracy: 68.12% **
# --------------------------------------------

# %%
combinations = [ ["P", "S"], ["C", "S"], ["S", "P"], ["S", "C"]]

# %%
for comb in combinations:
  print(f"------------Combination: {comb}--------------")
  lambda_irm_pair = [15.0, 5.0, 0.0]
  lambda_sparse=[0.1, 0.1, 0.1]

  trained_model_sae_office = train_model_irm_sae_with_warmup_office(
              batch_size=32,
              num_warmup_epochs=4,
              num_main_epochs=10,
              lr=6e-6,
              lr_sae=5e-5,
              lambda_irm=1.0,
              lambda_sae_rec=2.0,
              lambda_sae_sparse=2e-4,
              device='cuda',
              verbose=True,
              lambda_irm_pair=lambda_irm_pair,
              lambda_sparse=lambda_sparse,
              loader=comb
          )

  print("--------------------------------------------")
# Out:
# ------------Combination: ['P', 'S']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/53], IRM Loss: 14.6500, SAE Loss: 5.2696
# ** End of Epoch 1/10 | Test Accuracy: 4.07% **
# Epoch [2/10], Step [40/53], IRM Loss: 1.0058, SAE Loss: 7.2604
# ** End of Epoch 2/10 | Test Accuracy: 30.11% **
# Epoch [3/10], Step [40/53], IRM Loss: 0.3876, SAE Loss: 9.3735
# ** End of Epoch 3/10 | Test Accuracy: 31.31% **
# Epoch [4/10], Step [40/53], IRM Loss: 0.1682, SAE Loss: 7.7659
# ** End of Epoch 4/10 | Test Accuracy: 31.71% **
# Epoch [5/10], Step [40/53], IRM Loss: 0.1114, SAE Loss: 7.8076
# ** End of Epoch 5/10 | Test Accuracy: 31.81% **
# Epoch [6/10], Step [40/53], IRM Loss: 0.0951, SAE Loss: 8.0425
# ** End of Epoch 6/10 | Test Accuracy: 31.74% **
# Epoch [7/10], Step [40/53], IRM Loss: 0.0799, SAE Loss: 8.2946
# ** End of Epoch 7/10 | Test Accuracy: 31.84% **
# Epoch [8/10], Step [40/53], IRM Loss: 0.0797, SAE Loss: 9.7973
# ** End of Epoch 8/10 | Test Accuracy: 31.87% **
# Epoch [9/10], Step [40/53], IRM Loss: 0.0722, SAE Loss: 8.5348
# ** End of Epoch 9/10 | Test Accuracy: 31.79% **
# Epoch [10/10], Step [40/53], IRM Loss: 0.0538, SAE Loss: 8.9210
# ** End of Epoch 10/10 | Test Accuracy: 31.89% **
# --------------------------------------------
# ------------Combination: ['C', 'S']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/74], IRM Loss: 16.5814, SAE Loss: 6.1120
# ** End of Epoch 1/10 | Test Accuracy: 18.83% **
# Epoch [2/10], Step [40/74], IRM Loss: 4.9447, SAE Loss: 5.1464
# ** End of Epoch 2/10 | Test Accuracy: 24.23% **
# Epoch [3/10], Step [40/74], IRM Loss: 0.3750, SAE Loss: 5.7231
# ** End of Epoch 3/10 | Test Accuracy: 38.74% **
# Epoch [4/10], Step [40/74], IRM Loss: 0.2525, SAE Loss: 6.1602
# ** End of Epoch 4/10 | Test Accuracy: 33.24% **
# Epoch [5/10], Step [40/74], IRM Loss: 0.1416, SAE Loss: 6.2859
# ** End of Epoch 5/10 | Test Accuracy: 32.40% **
# Epoch [6/10], Step [40/74], IRM Loss: 0.0860, SAE Loss: 6.1420
# ** End of Epoch 6/10 | Test Accuracy: 34.64% **
# Epoch [7/10], Step [40/74], IRM Loss: 0.0696, SAE Loss: 6.7631
# ** End of Epoch 7/10 | Test Accuracy: 34.44% **
# Epoch [8/10], Step [40/74], IRM Loss: 0.0634, SAE Loss: 6.3576
# ** End of Epoch 8/10 | Test Accuracy: 34.54% **
# Epoch [9/10], Step [40/74], IRM Loss: 0.0523, SAE Loss: 6.4618
# ** End of Epoch 9/10 | Test Accuracy: 34.64% **
# Epoch [10/10], Step [40/74], IRM Loss: 0.0419, SAE Loss: 6.6858
# ** End of Epoch 10/10 | Test Accuracy: 34.51% **
# --------------------------------------------
# ------------Combination: ['S', 'P']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/123], IRM Loss: 16.9507, SAE Loss: 4.5846
# Epoch [1/10], Step [80/123], IRM Loss: 12.6688, SAE Loss: 3.4801
# Epoch [1/10], Step [120/123], IRM Loss: 9.7426, SAE Loss: 3.4846
# ** End of Epoch 1/10 | Test Accuracy: 15.21% **
# Epoch [2/10], Step [40/123], IRM Loss: 6.1139, SAE Loss: 2.6824
# Epoch [2/10], Step [80/123], IRM Loss: 4.3863, SAE Loss: 3.0138
# Epoch [2/10], Step [120/123], IRM Loss: 3.9444, SAE Loss: 2.9312
# ** End of Epoch 2/10 | Test Accuracy: 34.79% **
# Epoch [3/10], Step [40/123], IRM Loss: 2.6473, SAE Loss: 3.0908
# Epoch [3/10], Step [80/123], IRM Loss: 1.0748, SAE Loss: 2.8159
# Epoch [3/10], Step [120/123], IRM Loss: 2.2152, SAE Loss: 2.8259
# ** End of Epoch 3/10 | Test Accuracy: 41.02% **
# Epoch [4/10], Step [40/123], IRM Loss: 0.2933, SAE Loss: 2.7035
# Epoch [4/10], Step [80/123], IRM Loss: 0.1981, SAE Loss: 3.0717
# Epoch [4/10], Step [120/123], IRM Loss: 0.2997, SAE Loss: 3.0850
# ** End of Epoch 4/10 | Test Accuracy: 45.21% **
# Epoch [5/10], Step [40/123], IRM Loss: 0.1035, SAE Loss: 2.9254
# Epoch [5/10], Step [80/123], IRM Loss: 0.1415, SAE Loss: 2.5725
# Epoch [5/10], Step [120/123], IRM Loss: 0.0930, SAE Loss: 2.7155
# ** End of Epoch 5/10 | Test Accuracy: 42.93% **
# Epoch [6/10], Step [40/123], IRM Loss: 0.0894, SAE Loss: 2.8120
# Epoch [6/10], Step [80/123], IRM Loss: 0.0587, SAE Loss: 3.1365
# Epoch [6/10], Step [120/123], IRM Loss: 0.0601, SAE Loss: 3.0485
# ** End of Epoch 6/10 | Test Accuracy: 44.25% **
# Epoch [7/10], Step [40/123], IRM Loss: 0.0507, SAE Loss: 2.8938
# Epoch [7/10], Step [80/123], IRM Loss: 0.0471, SAE Loss: 2.8956
# Epoch [7/10], Step [120/123], IRM Loss: 0.0449, SAE Loss: 2.9815
# ** End of Epoch 7/10 | Test Accuracy: 44.61% **
# Epoch [8/10], Step [40/123], IRM Loss: 0.0405, SAE Loss: 3.1179
# Epoch [8/10], Step [80/123], IRM Loss: 0.0456, SAE Loss: 3.2824
# Epoch [8/10], Step [120/123], IRM Loss: 0.0353, SAE Loss: 3.0885
# ** End of Epoch 8/10 | Test Accuracy: 45.27% **
# Epoch [9/10], Step [40/123], IRM Loss: 0.0349, SAE Loss: 3.2443
# Epoch [9/10], Step [80/123], IRM Loss: 0.0363, SAE Loss: 3.1905
# Epoch [9/10], Step [120/123], IRM Loss: 0.0387, SAE Loss: 3.4186
# ** End of Epoch 9/10 | Test Accuracy: 45.63% **
# Epoch [10/10], Step [40/123], IRM Loss: 0.0322, SAE Loss: 3.3237
# Epoch [10/10], Step [80/123], IRM Loss: 0.0306, SAE Loss: 2.9779
# Epoch [10/10], Step [120/123], IRM Loss: 0.0325, SAE Loss: 3.3231
# ** End of Epoch 10/10 | Test Accuracy: 45.93% **
# --------------------------------------------
# ------------Combination: ['S', 'C']--------------
# ===== Main Phase (IRM + SAE) =====
# Epoch [1/10], Step [40/123], IRM Loss: 16.4606, SAE Loss: 5.1323
# Epoch [1/10], Step [80/123], IRM Loss: 13.2846, SAE Loss: 4.3734
# Epoch [1/10], Step [120/123], IRM Loss: 8.5750, SAE Loss: 3.7790
# ** End of Epoch 1/10 | Test Accuracy: 28.46% **
# Epoch [2/10], Step [40/123], IRM Loss: 6.5826, SAE Loss: 3.5249
# Epoch [2/10], Step [80/123], IRM Loss: 4.2644, SAE Loss: 3.7068
# Epoch [2/10], Step [120/123], IRM Loss: 3.5662, SAE Loss: 3.5152
# ** End of Epoch 2/10 | Test Accuracy: 48.17% **
# Epoch [3/10], Step [40/123], IRM Loss: 1.0624, SAE Loss: 3.1846
# Epoch [3/10], Step [80/123], IRM Loss: 0.6951, SAE Loss: 3.4927
# Epoch [3/10], Step [120/123], IRM Loss: 2.5453, SAE Loss: 3.2678
# ** End of Epoch 3/10 | Test Accuracy: 48.93% **
# Epoch [4/10], Step [40/123], IRM Loss: 0.3815, SAE Loss: 3.7017
# Epoch [4/10], Step [80/123], IRM Loss: 0.3854, SAE Loss: 3.1544
# Epoch [4/10], Step [120/123], IRM Loss: 0.2636, SAE Loss: 3.1372
# ** End of Epoch 4/10 | Test Accuracy: 60.96% **
# Epoch [5/10], Step [40/123], IRM Loss: 0.0970, SAE Loss: 3.4981
# Epoch [5/10], Step [80/123], IRM Loss: 0.0761, SAE Loss: 3.8386
# Epoch [5/10], Step [120/123], IRM Loss: 0.3441, SAE Loss: 3.2235
# ** End of Epoch 5/10 | Test Accuracy: 61.82% **
# Epoch [6/10], Step [40/123], IRM Loss: 0.0806, SAE Loss: 3.7581
# Epoch [6/10], Step [80/123], IRM Loss: 0.0541, SAE Loss: 3.7118
# Epoch [6/10], Step [120/123], IRM Loss: 0.0612, SAE Loss: 3.9173
# ** End of Epoch 6/10 | Test Accuracy: 61.31% **
# Epoch [7/10], Step [40/123], IRM Loss: 0.0617, SAE Loss: 4.0618
# Epoch [7/10], Step [80/123], IRM Loss: 0.0507, SAE Loss: 3.7116
# Epoch [7/10], Step [120/123], IRM Loss: 0.0984, SAE Loss: 3.8352
# ** End of Epoch 7/10 | Test Accuracy: 63.91% **
# Epoch [8/10], Step [40/123], IRM Loss: 0.0949, SAE Loss: 3.8645
# Epoch [8/10], Step [80/123], IRM Loss: 0.0394, SAE Loss: 3.5614
# Epoch [8/10], Step [120/123], IRM Loss: 0.0420, SAE Loss: 3.7677
# ** End of Epoch 8/10 | Test Accuracy: 61.99% **
# Epoch [9/10], Step [40/123], IRM Loss: 0.0377, SAE Loss: 3.4660
# Epoch [9/10], Step [80/123], IRM Loss: 0.0500, SAE Loss: 3.5201
# Epoch [9/10], Step [120/123], IRM Loss: 0.0312, SAE Loss: 3.5056
# ** End of Epoch 9/10 | Test Accuracy: 63.31% **
# Epoch [10/10], Step [40/123], IRM Loss: 0.0354, SAE Loss: 3.6157
# Epoch [10/10], Step [80/123], IRM Loss: 0.0315, SAE Loss: 3.5902
# Epoch [10/10], Step [120/123], IRM Loss: 0.0307, SAE Loss: 3.4258
# ** End of Epoch 10/10 | Test Accuracy: 62.76% **
# --------------------------------------------

# %% [markdown]
# ## Base Vit accuracies

# %%
from torchvision.models import vit_b_16
from tqdm.notebook import tqdm

def get_base_accuracy(loader=None):

    # print(f"------------Combination: {loader}--------------")

    loader_art_painting, loader_cartoon, loader_photo, loader_sketch = get_pacs_data_loaders(32)

    source, target = loader if loader is not None else ['P', 'C']

    if source == 'P':
        loader_source = loader_photo
    elif source == 'C':
        loader_source = loader_cartoon
    elif source == 'A':
        loader_source = loader_art_painting
    else:
        loader_source = loader_sketch

    if target == 'P':
        loader_target = loader_photo
    elif target == 'C':
        loader_target = loader_cartoon
    elif target == 'A':
        loader_target = loader_art_painting
    else:
        loader_target = loader_sketch


    model = vit_b_16(weights="DEFAULT")
    model.heads.head = nn.Linear(in_features=768, out_features=31, bias=True)
    model = model.to("cuda")

    optm = torch.optim.Adam(model.parameters(), lr=1e-5)
    epochs = 10

    for epoch in range(epochs):
        model.train()
        for x, y in (loader_source):
            x, y = x.to("cuda"), y.to("cuda")

            optm.zero_grad()
            logits = model(x)
            loss = F.cross_entropy(logits, y)
            loss.backward()
            optm.step()

        print(f"Epoch: {epoch+1}/{epochs} | Loss: {loss.item()}")

        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for x, y in (loader_target):
                x, y = x.to("cuda"), y.to("cuda")

                logits = model(x)
                preds = torch.argmax(logits, dim=1)
                correct += (preds == y).sum().item()
                total += y.size(0)
        acc = 100.0 * correct / total
        print(f"Epoch: {epoch+1}/{epochs} | Test Accuracy: {acc}")

        # print("--------------------------------------------")

# %%
combinations = [["P", "C"], ["P", "A"], ["P", "S"], ["C", "A"], ["C", "S"], ["C", "P"], ["A", "P"], ["A", "C"], ["A", "S"], ["S", "P"], ["S", "C"], ["S", "A"]]

for combination in combinations:
    print(f"------------Combination: {combination}--------------")
    get_base_accuracy(loader=combination)
    print("--------------------------------------------")
# Out:
# ------------Combination: ['P', 'C']--------------
# README.md:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/191M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9991 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/9991 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/9991 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/9991 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/9991 [00:00<?, ? examples/s]
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100%|██████████| 330M/330M [00:01<00:00, 216MB/s]
# Epoch: 1/10 | Loss: 0.6663272976875305
# Epoch: 1/10 | Test Accuracy: 24.914675767918087
# Epoch: 2/10 | Loss: 0.13300557434558868
# Epoch: 2/10 | Test Accuracy: 25.68259385665529
